# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in Dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss Dask vs. Pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance, and the data, along with its description, is available via [Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset).
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# <div>
# <image src="./images/02_medallion_architecture.png" height=300>
# </div>
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class to control the process of obtaining and transforming our data.
#
# <div>
# <image src="./images/02_target_pipeline_manager.png" height=250>
# </div>

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account. Alternatively, download the file from [this location](https://drive.google.com/drive/folders/1AA4gapDLpI194TGce1bY25sd91Km-tU3?usp=drive_link).
#
# + Extract stock prices (not ETFs) into the directory: `./05_src/data/prices_csv/`.
# + To be clear, your folder structure should include the path `05_src/data/prices_csv/stocks`.

# %% [markdown]
# The command `%run update_path.py` runs a local script that adds the repository's `./05_src/` directory to the Notebook's kernel path. This way, we can use our modules within the notebook.

# %%
# %run update_path.py

# %% [markdown]
# To load the historical price data for stocks and ETFs, use the code below. Notice the following:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager. Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by [Python's documentation](https://docs.python.org/2/howto/logging.html#logging-advanced-tutorial).

# %%
from glob import glob
import os
import pandas as pd
import random

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# + The [`glob` module](https://docs.python.org/3/library/glob.html) is used for finding path names that match specified patterns using Unix shell-style rules.
#
# + Notice that the module `glob` contains a function called `glob`; therefore, we used `from glob import glob` above.
#
# + The path in which we are searching for our csv files is produced by joining two strings:
#
#
#
#     - The value of the environment variable 'SRC_DIR' that we obtain with `os.getenv('SRC_DIR')` (this variable points to ./05_src).
#
#     - Another string given by "data/prices_csv/stocks/*.csv".
#
#     - Both strings are combined into an OS-consistent path using `os.path.join(...)`.
#
# + After we know the location of all our files, we sample a subset of them.

# %%
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))
_logs.info(f'Found {len(stock_files)} stock price files.')

random.seed(42)
n_sample = 60
stock_files = random.sample(stock_files, n_sample)
_logs.info(f'Sampled {n_sample} stock price files for processing. The files are: {stock_files   }')
# Out:
# 2026-01-19 22:55:40,944, 3619788285.py, 2, INFO, Found 5884 stock price files.
# 2026-01-19 22:55:40,944, 3619788285.py, 7, INFO, Sampled 60 stock price files for processing. The files are: ['../../05_src/data/prices_csv/stocks/HCM.csv', '../../05_src/data/prices_csv/stocks/ATHM.csv', '../../05_src/data/prices_csv/stocks/RILYP.csv', '../../05_src/data/prices_csv/stocks/ALDX.csv', '../../05_src/data/prices_csv/stocks/JHG.csv', '../../05_src/data/prices_csv/stocks/CHRS.csv', '../../05_src/data/prices_csv/stocks/BKTI.csv', '../../05_src/data/prices_csv/stocks/REFR.csv', '../../05_src/data/prices_csv/stocks/KEN.csv', '../../05_src/data/prices_csv/stocks/MDRRP.csv', '../../05_src/data/prices_csv/stocks/GRF.csv', '../../05_src/data/prices_csv/stocks/KRC.csv', '../../05_src/data/prices_csv/stocks/MICT.csv', '../../05_src/data/prices_csv/stocks/AMPY.csv', '../../05_src/data/prices_csv/stocks/A.csv', '../../05_src/data/prices_csv/stocks/WRLSU.csv', '../../05_src/data/prices_csv/stocks/PNR.csv', '../../05_src/data/prices_csv/stocks/TERP.csv', '../../05_src/data/prices_csv/stocks/TMSR.csv', '../../05_src/data/prices_csv/stocks/TDJ.csv', '../../05_src/data/prices_csv/stocks/CIK.csv', '../../05_src/data/prices_csv/stocks/SMBC.csv', '../../05_src/data/prices_csv/stocks/CNSP.csv', '../../05_src/data/prices_csv/stocks/BLK.csv', '../../05_src/data/prices_csv/stocks/CLNC.csv', '../../05_src/data/prices_csv/stocks/AOSL.csv', '../../05_src/data/prices_csv/stocks/LYV.csv', '../../05_src/data/prices_csv/stocks/IX.csv', '../../05_src/data/prices_csv/stocks/AWRE.csv', '../../05_src/data/prices_csv/stocks/KNX.csv', '../../05_src/data/prices_csv/stocks/TRXC.csv', '../../05_src/data/prices_csv/stocks/CVCY.csv', '../../05_src/data/prices_csv/stocks/UVE.csv', '../../05_src/data/prices_csv/stocks/HCKT.csv', '../../05_src/data/prices_csv/stocks/TFSL.csv', '../../05_src/data/prices_csv/stocks/ACB.csv', '../../05_src/data/prices_csv/stocks/AXP.csv', '../../05_src/data/prices_csv/stocks/GLG.csv', '../../05_src/data/prices_csv/stocks/MFO.csv', '../../05_src/data/prices_csv/stocks/PCB.csv', '../../05_src/data/prices_csv/stocks/IPDN.csv', '../../05_src/data/prices_csv/stocks/DTW.csv', '../../05_src/data/prices_csv/stocks/IQV.csv', '../../05_src/data/prices_csv/stocks/EVRI.csv', '../../05_src/data/prices_csv/stocks/LIVE.csv', '../../05_src/data/prices_csv/stocks/KZR.csv', '../../05_src/data/prices_csv/stocks/SO.csv', '../../05_src/data/prices_csv/stocks/INFY.csv', '../../05_src/data/prices_csv/stocks/BSE.csv', '../../05_src/data/prices_csv/stocks/PSN.csv', '../../05_src/data/prices_csv/stocks/TNAV.csv', '../../05_src/data/prices_csv/stocks/APTX.csv', '../../05_src/data/prices_csv/stocks/LAZY.csv', '../../05_src/data/prices_csv/stocks/DK.csv', '../../05_src/data/prices_csv/stocks/ZEUS.csv', '../../05_src/data/prices_csv/stocks/IRBT.csv', '../../05_src/data/prices_csv/stocks/AMAT.csv', '../../05_src/data/prices_csv/stocks/PSB.csv', '../../05_src/data/prices_csv/stocks/CTSO.csv', '../../05_src/data/prices_csv/stocks/UEC.csv']

# %% [markdown]
# We load the sampled files into dataframes and concatenate them:
#
# + Start with an empty list.
# + Read each file into a dataframe and [`append()` it to the list](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists). Notice that `append()` is an in-place operation (it does not return a list, it modifies the list in place).
# + Finally, we concatenate all dataframes along the vertical axis (`axis=0`) using [`pd.concat()`](https://pandas.pydata.org/docs/user_guide/merging.html#concat).
# + Notice that we do not concatenate each time that we load a dataframe. According to [Panda's documentation](https://pandas.pydata.org/docs/user_guide/merging.html#concat):
#
# > "`concat()` makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`."

# %%
dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2026-01-19 23:03:21,553, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCM.csv
# 2026-01-19 23:03:21,562, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ATHM.csv
# 2026-01-19 23:03:21,565, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RILYP.csv
# 2026-01-19 23:03:21,567, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ALDX.csv
# 2026-01-19 23:03:21,570, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/JHG.csv
# 2026-01-19 23:03:21,572, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CHRS.csv
# 2026-01-19 23:03:21,576, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BKTI.csv
# 2026-01-19 23:03:21,583, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/REFR.csv
# 2026-01-19 23:03:21,588, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KEN.csv
# 2026-01-19 23:03:21,590, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MDRRP.csv
# 2026-01-19 23:03:21,591, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GRF.csv
# 2026-01-19 23:03:21,594, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KRC.csv
# 2026-01-19 23:03:21,598, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MICT.csv
# 2026-01-19 23:03:21,601, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMPY.csv
# 2026-01-19 23:03:21,603, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/A.csv
# 2026-01-19 23:03:21,606, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WRLSU.csv
# 2026-01-19 23:03:21,608, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PNR.csv
# 2026-01-19 23:03:21,614, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TERP.csv
# 2026-01-19 23:03:21,616, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TMSR.csv
# 2026-01-19 23:03:21,617, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TDJ.csv
# 2026-01-19 23:03:21,619, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CIK.csv
# 2026-01-19 23:03:21,624, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SMBC.csv
# 2026-01-19 23:03:21,627, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CNSP.csv
# 2026-01-19 23:03:21,628, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BLK.csv
# 2026-01-19 23:03:21,631, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CLNC.csv
# 2026-01-19 23:03:21,632, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AOSL.csv
# 2026-01-19 23:03:21,634, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LYV.csv
# 2026-01-19 23:03:21,637, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IX.csv
# 2026-01-19 23:03:21,640, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AWRE.csv
# 2026-01-19 23:03:21,643, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KNX.csv
# 2026-01-19 23:03:21,647, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TRXC.csv
# 2026-01-19 23:03:21,650, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CVCY.csv
# 2026-01-19 23:03:21,653, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UVE.csv
# 2026-01-19 23:03:21,656, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCKT.csv
# 2026-01-19 23:03:21,659, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TFSL.csv
# 2026-01-19 23:03:21,661, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ACB.csv
# 2026-01-19 23:03:21,664, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AXP.csv
# 2026-01-19 23:03:21,670, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GLG.csv
# 2026-01-19 23:03:21,672, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MFO.csv
# 2026-01-19 23:03:21,674, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PCB.csv
# 2026-01-19 23:03:21,676, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IPDN.csv
# 2026-01-19 23:03:21,677, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DTW.csv
# 2026-01-19 23:03:21,679, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IQV.csv
# 2026-01-19 23:03:21,680, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EVRI.csv
# 2026-01-19 23:03:21,683, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LIVE.csv
# 2026-01-19 23:03:21,685, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KZR.csv
# 2026-01-19 23:03:21,686, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SO.csv
# 2026-01-19 23:03:21,691, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/INFY.csv
# 2026-01-19 23:03:21,694, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BSE.csv
# 2026-01-19 23:03:21,696, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSN.csv
# 2026-01-19 23:03:21,698, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TNAV.csv
# 2026-01-19 23:03:21,700, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/APTX.csv
# 2026-01-19 23:03:21,702, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LAZY.csv
# 2026-01-19 23:03:21,708, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DK.csv
# 2026-01-19 23:03:21,714, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ZEUS.csv
# 2026-01-19 23:03:21,717, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IRBT.csv
# 2026-01-19 23:03:21,720, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMAT.csv
# 2026-01-19 23:03:21,724, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSB.csv
# 2026-01-19 23:03:21,728, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CTSO.csv
# 2026-01-19 23:03:21,730, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UEC.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data using the [`info()` dataframe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230273 entries, 0 to 230272
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       230273 non-null  datetime64[ns]
#  1   Open       230260 non-null  float64
#  2   High       230260 non-null  float64
#  3   Low        230260 non-null  float64
#  4   Close      230260 non-null  float64
#  5   Adj Close  230260 non-null  float64
#  6   Volume     230260 non-null  float64
#  7   source     230273 non-null  object
#  8   ticker     230273 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 15.8+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. Good references for this type of data manipulation are:
#
# + [Panda's Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data).
# + [Panda's Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['HCM',
#  'ATHM',
#  'RILYP',
#  'ALDX',
#  'JHG',
#  'CHRS',
#  'BKTI',
#  'REFR',
#  'KEN',
#  'MDRRP',
#  'GRF',
#  'KRC',
#  'MICT',
#  'AMPY',
#  'A',
#  'WRLSU',
#  'PNR',
#  'TERP',
#  'TMSR',
#  'TDJ',
#  'CIK',
#  'SMBC',
#  'CNSP',
#  'BLK',
#  'CLNC',
#  'AOSL',
#  'LYV',
#  'IX',
#  'AWRE',
#  'KNX',
#  'TRXC',
#  'CVCY',
#  'UVE',
#  'HCKT',
#  'TFSL',
#  'ACB',
#  'AXP',
#  'GLG',
#  'MFO',
#  'PCB',
#  'IPDN',
#  'DTW',
#  'IQV',
#  'EVRI',
#  'LIVE',
#  'KZR',
#  'SO',
#  'INFY',
#  'BSE',
#  'PSN',
#  'TNAV',
#  'APTX',
#  'LAZY',
#  'DK',
#  'ZEUS',
#  'IRBT',
#  'AMAT',
#  'PSB',
#  'CTSO',
#  'UEC']

# %% [markdown]
# # Storing Data in CSV
#
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parquet, by measuring their performance:
#
#     - Time to save: We will measure time by using the `time` library.
#     - Space required on drive: We will use the custom function below.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %% [markdown]
# Load the specification of a temporary directory from the environment  and create a subdirectory in it called "csv":
#
# + Use `os.getenv("TEMP_DATA")` to obtain the desired location of the temporary folder from an environment variable.
# + If the subdirectory exists, delete it using `shutil.rmtree()`; the flag `ignore_errors=True` helps us in case the subdirectory does not exist (for instance, in the first run).
# + Create a directory with path given by `csv_dir` using `os.makedirs()`; the flag `exist_ok=True` indicates that if the directory already exists, then the function will do nothing.
# + Finally, create the stock price file location, `stock_csv`, which will be used to create the csv file.

# %%
import shutil

temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")

shutil.rmtree(csv_dir, ignore_errors=True)
os.makedirs(csv_dir, exist_ok=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")

# %% [markdown]
# Save the concatenated dataframe to a CSV file. We measure the time elapsed by storing the start and end times, then we calculate their difference in seconds.

# %%
import time

start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2026-01-19 23:17:22,631, 807204384.py, 7, INFO, Writing data ((230273, 9)) to csv took 0.6135208606719971 seconds.
# 2026-01-19 23:17:22,631, 807204384.py, 8, INFO, CSV file size 25.988193 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Notes on Dask
#
# We could use Pandas to save the data directly into Parquet files. However, we will use a different approach by applying the [Dask framework](https://www.dask.org/). Dask provides functionality for working with datasets that do not fit in memory and parallelization to speed up computation. A few notes on Dask and Pandas:
#
# - Pandas, Parquet, and Arrow:
#
#     + We can work with large datasets and Parquet files in Pandas, but we will generally be limited by the amount of data that can fit in our computer's memory.
#     + Pandas can write Parquet files using a PyArrow backend. In fact, recent versions of Pandas support PyArrow data types, and future versions will require a PyArrow backend.
#     + The PyArrow library is an interface between Python and the Apache Arrow project. In particular, the [Parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are Apache projects.
#
# - Dask
#
#     + Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on Pandas-like dataframes.
#     + Dask is also relatively easy to use as it mimics Pandas' API.
#     + Dask allows us to work with larger datasets than Pandas. In a sense, it is an intermediate step between Pandas and big-data frameworks like Spark (or Databricks).
#     + If you are familiar with Pandas, a good introduction is [10 Minutes to Dask](https://docs.dask.org/en/stable/10-minutes-to-dask.html).

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2026-01-19 23:20:29,460, 817812245.py, 7, INFO, Writing dd ((230273, 9)) to parquet took 0.12944698333740234 seconds.
# 2026-01-19 23:20:29,461, 817812245.py, 8, INFO, Parquet file size 8.889431 MB

# %% [markdown]
# ### Pandas, Dask, and Parquet
#
# The distinction of Pandas Dataframes, Dask Dataframes, and Parquet files is important:
#
# + Pandas dataframes combine the functionality of [NumPy](https://numpy.org/) (efficient vector operations, especially vector algebra) with a concise data manipulation framework that allows us to create columns of different data types (NumPy only allows single-type matrices), database-like operations (such as filtering rows, subsetting columns, and joining different dataframes).
# + Dask dataframes extend the functionality of Pandas dataframes beyond the confines of available memory and implement parallelized operations, among other benefits.
# + Parquet files are a file format. Parquet files can be created by Pandas and Dask, but Dask offers a superior interface. Parquet files are immutable: once written, they cannot be modified.
# + Parquet and Dask are not the same: Parquet is a file format that can be accessed by many applications and programming languages (Python, R, Power BI, etc.), while Dask is a Python package for working with large datasets using distributed computation.

# %% [markdown]
# ### Dask is Powerful, but not Infallible
#
# It is tempting to think of Dask as a super-Pandas, but each package has its advantages and disadvantages.
#
# + Dask is not good at everything (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
# + A useful and somewhat idiosyncratic comparison of various data manipulation frameworks is shown below (from [DataFrames at Scale Comparison: TPC-H](https://docs.coiled.io/blog/tpch.html#when-to-use-duckdb-vs-polars-vs-dask-vs-spark))
#
# Concept              | Spark | Dask | DuckDB | Polars
# ---------------------|-------|------|--------|--------
# Fast Locally         | ❌    | 🤔  | ✅     | ✅
# Fast on Cloud (1 TB) | ✅    | ✅  | ✅     | ❌
# Fast on Cloud (10 TB)| ❌    | ✅  | ✅     | ❌
# Scales Out           | ✅    | ✅  | ❌     | ❌
# SQL                  | ✅    | 🤔  | ✅     | 🤔
# More than SQL        | ✅    | ✅  | ❌     | ✅
# Sensible Defaults    | ❌    | ✅  | ✅     | ✅
#
#
# ### Dask Best Practices
#
# Parallelism brings extra complexity and overhead. Here are a few ideas to help you decide when to use Dask (from [Dask's Best Practices](https://docs.dask.org/en/stable/best-practices.html)):
#
# #### Small is Better
#
# + Start small: if possible, use Pandas. Also, try to reduce your data using aggregation, then use Pandas.
# + More generally, NumPy, Pandas, and Scikit-Learn may have faster functions for what you need. Consult the relevant documentation, experiment, and/or consult with a colleague or expert.
#
# #### Index with Care
#
# + Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
# + Minimize full-data shuffling as much as possible: indexing is an expensive operation.
#
# ### Consider the Cost of Joins
#
# + Consider cases such as small-to-large joins, where the small dataframe fits in memory, but the large one does not. The small dataframe can be Pandas, while the larger one is a Dask dataframe.
# + Some joins are more expensive than others.
#
#     * Not expensive:
#
#         - Join a Dask DataFrame with a Pandas DataFrame.
#         - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#         - Join Dask DataFrames along their indexes.
#
#     * Expensive:
#
#         - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How Do We Store Prices?
#
# + We can store our data as a single blob.
#
#   - This can be difficult to maintain, especially because parquet files are immutable.
#   - Using a single file, we would need to recreate the complete file any time that we update it.
#
# + An alternative strategy is to organize data files by ticker and date:
#
#   - We can create one file per ticker and month (or any other suitable frequency).
#   - Under this approach, we would only need to recreate the latest month's file at any update.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    # Filter data for ticker
    # Notice that these are Pandas dataframes
    _logs.info(f'Processing ticker: {ticker}')
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        _logs.info(f'Processing year {yr} for ticker {ticker}.')
        # Filter data for year and convert to Dask dataframe
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        
        # Define path and create directories if not exist
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        _logs.info(f'Writing data to path: {yr_path}')

        # Write to Parquet
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# 2026-01-19 23:26:06,145, 2113979629.py, 4, INFO, Processing ticker: HCM
# 2026-01-19 23:26:06,155, 2113979629.py, 8, INFO, Processing year 2016 for ticker HCM.
# 2026-01-19 23:26:06,160, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2016
# 2026-01-19 23:26:06,169, 2113979629.py, 8, INFO, Processing year 2017 for ticker HCM.
# 2026-01-19 23:26:06,171, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2017
# 2026-01-19 23:26:06,178, 2113979629.py, 8, INFO, Processing year 2018 for ticker HCM.
# 2026-01-19 23:26:06,179, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2018
# 2026-01-19 23:26:06,185, 2113979629.py, 8, INFO, Processing year 2019 for ticker HCM.
# 2026-01-19 23:26:06,186, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2019
# 2026-01-19 23:26:06,191, 2113979629.py, 8, INFO, Processing year 2020 for ticker HCM.
# 2026-01-19 23:26:06,193, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2020
# 2026-01-19 23:26:06,197, 2113979629.py, 4, INFO, Processing ticker: ATHM
# 2026-01-19 23:26:06,203, 2113979629.py, 8, INFO, Processing year 2013 for ticker ATHM.
# 2026-01-19 23:26:06,205, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2013
# 2026-01-19 23:26:06,210, 2113979629.py, 8, INFO, Processing year 2014 for ticker ATHM.
# 2026-01-19 23:26:06,211, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2014
# 2026-01-19 23:26:06,217, 2113979629.py, 8, INFO, Processing year 2015 for ticker ATHM.
# 2026-01-19 23:26:06,218, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2015
# 2026-01-19 23:26:06,223, 2113979629.py, 8, INFO, Processing year 2016 for ticker ATHM.
# 2026-01-19 23:26:06,224, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2016
# 2026-01-19 23:26:06,230, 2113979629.py, 8, INFO, Processing year 2017 for ticker ATHM.
# 2026-01-19 23:26:06,231, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2017
# 2026-01-19 23:26:06,235, 2113979629.py, 8, INFO, Processing year 2018 for ticker ATHM.
# 2026-01-19 23:26:06,237, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2018
# 2026-01-19 23:26:06,242, 2113979629.py, 8, INFO, Processing year 2019 for ticker ATHM.
# 2026-01-19 23:26:06,244, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2019
# 2026-01-19 23:26:06,248, 2113979629.py, 8, INFO, Processing year 2020 for ticker ATHM.
# 2026-01-19 23:26:06,250, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2020
# 2026-01-19 23:26:06,254, 2113979629.py, 4, INFO, Processing ticker: RILYP
# 2026-01-19 23:26:06,259, 2113979629.py, 8, INFO, Processing year 2020 for ticker RILYP.
# 2026-01-19 23:26:06,260, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/RILYP/RILYP_2020
# 2026-01-19 23:26:06,265, 2113979629.py, 4, INFO, Processing ticker: ALDX
# 2026-01-19 23:26:06,270, 2113979629.py, 8, INFO, Processing year 2014 for ticker ALDX.
# 2026-01-19 23:26:06,272, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2014
# 2026-01-19 23:26:06,277, 2113979629.py, 8, INFO, Processing year 2015 for ticker ALDX.
# 2026-01-19 23:26:06,279, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2015
# 2026-01-19 23:26:06,284, 2113979629.py, 8, INFO, Processing year 2016 for ticker ALDX.
# 2026-01-19 23:26:06,285, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2016
# 2026-01-19 23:26:06,290, 2113979629.py, 8, INFO, Processing year 2017 for ticker ALDX.
# 2026-01-19 23:26:06,292, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2017
# 2026-01-19 23:26:06,296, 2113979629.py, 8, INFO, Processing year 2018 for ticker ALDX.
# 2026-01-19 23:26:06,298, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2018
# 2026-01-19 23:26:06,302, 2113979629.py, 8, INFO, Processing year 2019 for ticker ALDX.
# 2026-01-19 23:26:06,308, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2019
# 2026-01-19 23:26:06,316, 2113979629.py, 8, INFO, Processing year 2020 for ticker ALDX.
# 2026-01-19 23:26:06,317, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2020
# 2026-01-19 23:26:06,323, 2113979629.py, 4, INFO, Processing ticker: JHG
# 2026-01-19 23:26:06,329, 2113979629.py, 8, INFO, Processing year 2017 for ticker JHG.
# 2026-01-19 23:26:06,333, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2017
# 2026-01-19 23:26:06,363, 2113979629.py, 8, INFO, Processing year 2018 for ticker JHG.
# 2026-01-19 23:26:06,365, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2018
# 2026-01-19 23:26:06,370, 2113979629.py, 8, INFO, Processing year 2019 for ticker JHG.
# 2026-01-19 23:26:06,372, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2019
# 2026-01-19 23:26:06,379, 2113979629.py, 8, INFO, Processing year 2020 for ticker JHG.
# 2026-01-19 23:26:06,381, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2020
# 2026-01-19 23:26:06,386, 2113979629.py, 4, INFO, Processing ticker: CHRS
# 2026-01-19 23:26:06,393, 2113979629.py, 8, INFO, Processing year 2001 for ticker CHRS.
# 2026-01-19 23:26:06,396, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2001
# 2026-01-19 23:26:06,404, 2113979629.py, 8, INFO, Processing year 2002 for ticker CHRS.
# 2026-01-19 23:26:06,406, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2002
# 2026-01-19 23:26:06,412, 2113979629.py, 8, INFO, Processing year 2003 for ticker CHRS.
# 2026-01-19 23:26:06,413, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2003
# 2026-01-19 23:26:06,419, 2113979629.py, 8, INFO, Processing year 2005 for ticker CHRS.
# 2026-01-19 23:26:06,420, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2005
# 2026-01-19 23:26:06,427, 2113979629.py, 8, INFO, Processing year 2006 for ticker CHRS.
# 2026-01-19 23:26:06,428, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2006
# 2026-01-19 23:26:06,437, 2113979629.py, 8, INFO, Processing year 2007 for ticker CHRS.
# 2026-01-19 23:26:06,438, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2007
# 2026-01-19 23:26:06,444, 2113979629.py, 8, INFO, Processing year 2008 for ticker CHRS.
# 2026-01-19 23:26:06,445, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2008
# 2026-01-19 23:26:06,450, 2113979629.py, 8, INFO, Processing year 2011 for ticker CHRS.
# 2026-01-19 23:26:06,452, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2011
# 2026-01-19 23:26:06,459, 2113979629.py, 8, INFO, Processing year 2012 for ticker CHRS.
# 2026-01-19 23:26:06,461, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2012
# 2026-01-19 23:26:06,466, 2113979629.py, 8, INFO, Processing year 2013 for ticker CHRS.
# 2026-01-19 23:26:06,467, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2013
# 2026-01-19 23:26:06,475, 2113979629.py, 8, INFO, Processing year 2014 for ticker CHRS.
# 2026-01-19 23:26:06,477, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2014
# 2026-01-19 23:26:06,483, 2113979629.py, 8, INFO, Processing year 2015 for ticker CHRS.
# 2026-01-19 23:26:06,484, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2015
# 2026-01-19 23:26:06,490, 2113979629.py, 8, INFO, Processing year 2016 for ticker CHRS.
# 2026-01-19 23:26:06,491, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2016
# 2026-01-19 23:26:06,500, 2113979629.py, 8, INFO, Processing year 2017 for ticker CHRS.
# 2026-01-19 23:26:06,501, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2017
# 2026-01-19 23:26:06,507, 2113979629.py, 8, INFO, Processing year 2018 for ticker CHRS.
# 2026-01-19 23:26:06,509, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2018
# 2026-01-19 23:26:06,517, 2113979629.py, 8, INFO, Processing year 2019 for ticker CHRS.
# 2026-01-19 23:26:06,523, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2019
# 2026-01-19 23:26:06,529, 2113979629.py, 8, INFO, Processing year 2020 for ticker CHRS.
# 2026-01-19 23:26:06,530, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2020
# 2026-01-19 23:26:06,536, 2113979629.py, 4, INFO, Processing ticker: BKTI
# 2026-01-19 23:26:06,542, 2113979629.py, 8, INFO, Processing year 1980 for ticker BKTI.
# 2026-01-19 23:26:06,544, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1980
# 2026-01-19 23:26:06,549, 2113979629.py, 8, INFO, Processing year 1981 for ticker BKTI.
# 2026-01-19 23:26:06,551, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1981
# 2026-01-19 23:26:06,558, 2113979629.py, 8, INFO, Processing year 1982 for ticker BKTI.
# 2026-01-19 23:26:06,560, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1982
# 2026-01-19 23:26:06,565, 2113979629.py, 8, INFO, Processing year 1983 for ticker BKTI.
# 2026-01-19 23:26:06,566, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1983
# 2026-01-19 23:26:06,575, 2113979629.py, 8, INFO, Processing year 1984 for ticker BKTI.
# 2026-01-19 23:26:06,577, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1984
# 2026-01-19 23:26:06,582, 2113979629.py, 8, INFO, Processing year 1985 for ticker BKTI.
# 2026-01-19 23:26:06,584, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1985
# 2026-01-19 23:26:06,592, 2113979629.py, 8, INFO, Processing year 1986 for ticker BKTI.
# 2026-01-19 23:26:06,593, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1986
# 2026-01-19 23:26:06,599, 2113979629.py, 8, INFO, Processing year 1987 for ticker BKTI.
# 2026-01-19 23:26:06,600, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1987
# 2026-01-19 23:26:06,605, 2113979629.py, 8, INFO, Processing year 1988 for ticker BKTI.
# 2026-01-19 23:26:06,607, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1988
# 2026-01-19 23:26:06,619, 2113979629.py, 8, INFO, Processing year 1989 for ticker BKTI.
# 2026-01-19 23:26:06,621, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1989
# 2026-01-19 23:26:06,626, 2113979629.py, 8, INFO, Processing year 1990 for ticker BKTI.
# 2026-01-19 23:26:06,628, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1990
# 2026-01-19 23:26:06,633, 2113979629.py, 8, INFO, Processing year 1991 for ticker BKTI.
# 2026-01-19 23:26:06,635, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1991
# 2026-01-19 23:26:06,640, 2113979629.py, 8, INFO, Processing year 1992 for ticker BKTI.
# 2026-01-19 23:26:06,642, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1992
# 2026-01-19 23:26:06,648, 2113979629.py, 8, INFO, Processing year 1993 for ticker BKTI.
# 2026-01-19 23:26:06,650, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1993
# 2026-01-19 23:26:06,660, 2113979629.py, 8, INFO, Processing year 1994 for ticker BKTI.
# 2026-01-19 23:26:06,662, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1994
# 2026-01-19 23:26:06,667, 2113979629.py, 8, INFO, Processing year 1995 for ticker BKTI.
# 2026-01-19 23:26:06,669, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1995
# 2026-01-19 23:26:06,674, 2113979629.py, 8, INFO, Processing year 1996 for ticker BKTI.
# 2026-01-19 23:26:06,676, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1996
# 2026-01-19 23:26:06,683, 2113979629.py, 8, INFO, Processing year 1997 for ticker BKTI.
# 2026-01-19 23:26:06,685, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1997
# 2026-01-19 23:26:06,690, 2113979629.py, 8, INFO, Processing year 1998 for ticker BKTI.
# 2026-01-19 23:26:06,692, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1998
# 2026-01-19 23:26:06,699, 2113979629.py, 8, INFO, Processing year 1999 for ticker BKTI.
# 2026-01-19 23:26:06,700, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1999
# 2026-01-19 23:26:06,706, 2113979629.py, 8, INFO, Processing year 2000 for ticker BKTI.
# 2026-01-19 23:26:06,708, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2000
# 2026-01-19 23:26:06,713, 2113979629.py, 8, INFO, Processing year 2001 for ticker BKTI.
# 2026-01-19 23:26:06,714, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2001
# 2026-01-19 23:26:06,721, 2113979629.py, 8, INFO, Processing year 2002 for ticker BKTI.
# 2026-01-19 23:26:06,723, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2002
# 2026-01-19 23:26:06,728, 2113979629.py, 8, INFO, Processing year 2003 for ticker BKTI.
# 2026-01-19 23:26:06,730, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2003
# 2026-01-19 23:26:06,735, 2113979629.py, 8, INFO, Processing year 2004 for ticker BKTI.
# 2026-01-19 23:26:06,736, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2004
# 2026-01-19 23:26:06,748, 2113979629.py, 8, INFO, Processing year 2005 for ticker BKTI.
# 2026-01-19 23:26:06,749, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2005
# 2026-01-19 23:26:06,755, 2113979629.py, 8, INFO, Processing year 2006 for ticker BKTI.
# 2026-01-19 23:26:06,756, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2006
# 2026-01-19 23:26:06,762, 2113979629.py, 8, INFO, Processing year 2007 for ticker BKTI.
# 2026-01-19 23:26:06,764, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2007
# 2026-01-19 23:26:06,768, 2113979629.py, 8, INFO, Processing year 2008 for ticker BKTI.
# 2026-01-19 23:26:06,770, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2008
# 2026-01-19 23:26:06,775, 2113979629.py, 8, INFO, Processing year 2009 for ticker BKTI.
# 2026-01-19 23:26:06,777, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2009
# 2026-01-19 23:26:06,787, 2113979629.py, 8, INFO, Processing year 2010 for ticker BKTI.
# 2026-01-19 23:26:06,789, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2010
# 2026-01-19 23:26:06,794, 2113979629.py, 8, INFO, Processing year 2011 for ticker BKTI.
# 2026-01-19 23:26:06,796, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2011
# 2026-01-19 23:26:06,802, 2113979629.py, 8, INFO, Processing year 2012 for ticker BKTI.
# 2026-01-19 23:26:06,803, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2012
# 2026-01-19 23:26:06,811, 2113979629.py, 8, INFO, Processing year 2013 for ticker BKTI.
# 2026-01-19 23:26:06,813, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2013
# 2026-01-19 23:26:06,818, 2113979629.py, 8, INFO, Processing year 2014 for ticker BKTI.
# 2026-01-19 23:26:06,820, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2014
# 2026-01-19 23:26:06,826, 2113979629.py, 8, INFO, Processing year 2015 for ticker BKTI.
# 2026-01-19 23:26:06,827, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2015
# 2026-01-19 23:26:06,837, 2113979629.py, 8, INFO, Processing year 2016 for ticker BKTI.
# 2026-01-19 23:26:06,839, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2016
# 2026-01-19 23:26:06,844, 2113979629.py, 8, INFO, Processing year 2017 for ticker BKTI.
# 2026-01-19 23:26:06,846, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2017
# 2026-01-19 23:26:06,854, 2113979629.py, 8, INFO, Processing year 2018 for ticker BKTI.
# 2026-01-19 23:26:06,856, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2018
# 2026-01-19 23:26:06,862, 2113979629.py, 8, INFO, Processing year 2019 for ticker BKTI.
# 2026-01-19 23:26:06,864, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2019
# 2026-01-19 23:26:06,874, 2113979629.py, 8, INFO, Processing year 2020 for ticker BKTI.
# 2026-01-19 23:26:06,876, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2020
# 2026-01-19 23:26:06,881, 2113979629.py, 4, INFO, Processing ticker: REFR
# 2026-01-19 23:26:06,887, 2113979629.py, 8, INFO, Processing year 1993 for ticker REFR.
# 2026-01-19 23:26:06,893, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1993
# 2026-01-19 23:26:06,899, 2113979629.py, 8, INFO, Processing year 1994 for ticker REFR.
# 2026-01-19 23:26:06,901, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1994
# 2026-01-19 23:26:06,911, 2113979629.py, 8, INFO, Processing year 1995 for ticker REFR.
# 2026-01-19 23:26:06,913, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1995
# 2026-01-19 23:26:06,919, 2113979629.py, 8, INFO, Processing year 1996 for ticker REFR.
# 2026-01-19 23:26:06,920, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1996
# 2026-01-19 23:26:06,926, 2113979629.py, 8, INFO, Processing year 1997 for ticker REFR.
# 2026-01-19 23:26:06,928, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1997
# 2026-01-19 23:26:06,936, 2113979629.py, 8, INFO, Processing year 1998 for ticker REFR.
# 2026-01-19 23:26:06,938, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1998
# 2026-01-19 23:26:06,943, 2113979629.py, 8, INFO, Processing year 1999 for ticker REFR.
# 2026-01-19 23:26:06,945, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1999
# 2026-01-19 23:26:06,952, 2113979629.py, 8, INFO, Processing year 2000 for ticker REFR.
# 2026-01-19 23:26:06,954, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2000
# 2026-01-19 23:26:06,959, 2113979629.py, 8, INFO, Processing year 2001 for ticker REFR.
# 2026-01-19 23:26:06,961, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2001
# 2026-01-19 23:26:06,970, 2113979629.py, 8, INFO, Processing year 2002 for ticker REFR.
# 2026-01-19 23:26:06,972, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2002
# 2026-01-19 23:26:06,979, 2113979629.py, 8, INFO, Processing year 2003 for ticker REFR.
# 2026-01-19 23:26:06,981, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2003
# 2026-01-19 23:26:06,986, 2113979629.py, 8, INFO, Processing year 2004 for ticker REFR.
# 2026-01-19 23:26:06,988, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2004
# 2026-01-19 23:26:06,993, 2113979629.py, 8, INFO, Processing year 2005 for ticker REFR.
# 2026-01-19 23:26:06,999, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2005
# 2026-01-19 23:26:07,007, 2113979629.py, 8, INFO, Processing year 2006 for ticker REFR.
# 2026-01-19 23:26:07,009, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2006
# 2026-01-19 23:26:07,016, 2113979629.py, 8, INFO, Processing year 2007 for ticker REFR.
# 2026-01-19 23:26:07,018, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2007
# 2026-01-19 23:26:07,023, 2113979629.py, 8, INFO, Processing year 2008 for ticker REFR.
# 2026-01-19 23:26:07,025, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2008
# 2026-01-19 23:26:07,033, 2113979629.py, 8, INFO, Processing year 2009 for ticker REFR.
# 2026-01-19 23:26:07,035, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2009
# 2026-01-19 23:26:07,041, 2113979629.py, 8, INFO, Processing year 2010 for ticker REFR.
# 2026-01-19 23:26:07,042, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2010
# 2026-01-19 23:26:07,048, 2113979629.py, 8, INFO, Processing year 2011 for ticker REFR.
# 2026-01-19 23:26:07,050, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2011
# 2026-01-19 23:26:07,058, 2113979629.py, 8, INFO, Processing year 2012 for ticker REFR.
# 2026-01-19 23:26:07,060, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2012
# 2026-01-19 23:26:07,068, 2113979629.py, 8, INFO, Processing year 2013 for ticker REFR.
# 2026-01-19 23:26:07,070, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2013
# 2026-01-19 23:26:07,075, 2113979629.py, 8, INFO, Processing year 2014 for ticker REFR.
# 2026-01-19 23:26:07,077, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2014
# 2026-01-19 23:26:07,082, 2113979629.py, 8, INFO, Processing year 2015 for ticker REFR.
# 2026-01-19 23:26:07,084, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2015
# 2026-01-19 23:26:07,089, 2113979629.py, 8, INFO, Processing year 2016 for ticker REFR.
# 2026-01-19 23:26:07,090, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2016
# 2026-01-19 23:26:07,099, 2113979629.py, 8, INFO, Processing year 2017 for ticker REFR.
# 2026-01-19 23:26:07,101, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2017
# 2026-01-19 23:26:07,106, 2113979629.py, 8, INFO, Processing year 2018 for ticker REFR.
# 2026-01-19 23:26:07,108, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2018
# 2026-01-19 23:26:07,113, 2113979629.py, 8, INFO, Processing year 2019 for ticker REFR.
# 2026-01-19 23:26:07,115, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2019
# 2026-01-19 23:26:07,123, 2113979629.py, 8, INFO, Processing year 2020 for ticker REFR.
# 2026-01-19 23:26:07,124, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2020
# 2026-01-19 23:26:07,130, 2113979629.py, 4, INFO, Processing ticker: KEN
# 2026-01-19 23:26:07,136, 2113979629.py, 8, INFO, Processing year 2015 for ticker KEN.
# 2026-01-19 23:26:07,137, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2015
# 2026-01-19 23:26:07,143, 2113979629.py, 8, INFO, Processing year 2016 for ticker KEN.
# 2026-01-19 23:26:07,145, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2016
# 2026-01-19 23:26:07,153, 2113979629.py, 8, INFO, Processing year 2017 for ticker KEN.
# 2026-01-19 23:26:07,155, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2017
# 2026-01-19 23:26:07,159, 2113979629.py, 8, INFO, Processing year 2018 for ticker KEN.
# 2026-01-19 23:26:07,161, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2018
# 2026-01-19 23:26:07,166, 2113979629.py, 8, INFO, Processing year 2019 for ticker KEN.
# 2026-01-19 23:26:07,167, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2019
# 2026-01-19 23:26:07,175, 2113979629.py, 8, INFO, Processing year 2020 for ticker KEN.
# 2026-01-19 23:26:07,176, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2020
# 2026-01-19 23:26:07,181, 2113979629.py, 4, INFO, Processing ticker: MDRRP
# 2026-01-19 23:26:07,186, 2113979629.py, 8, INFO, Processing year 2020 for ticker MDRRP.
# 2026-01-19 23:26:07,191, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MDRRP/MDRRP_2020
# 2026-01-19 23:26:07,196, 2113979629.py, 4, INFO, Processing ticker: GRF
# 2026-01-19 23:26:07,202, 2113979629.py, 8, INFO, Processing year 2004 for ticker GRF.
# 2026-01-19 23:26:07,207, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2004
# 2026-01-19 23:26:07,221, 2113979629.py, 8, INFO, Processing year 2005 for ticker GRF.
# 2026-01-19 23:26:07,223, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2005
# 2026-01-19 23:26:07,228, 2113979629.py, 8, INFO, Processing year 2006 for ticker GRF.
# 2026-01-19 23:26:07,230, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2006
# 2026-01-19 23:26:07,239, 2113979629.py, 8, INFO, Processing year 2007 for ticker GRF.
# 2026-01-19 23:26:07,241, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2007
# 2026-01-19 23:26:07,246, 2113979629.py, 8, INFO, Processing year 2008 for ticker GRF.
# 2026-01-19 23:26:07,248, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2008
# 2026-01-19 23:26:07,254, 2113979629.py, 8, INFO, Processing year 2009 for ticker GRF.
# 2026-01-19 23:26:07,255, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2009
# 2026-01-19 23:26:07,263, 2113979629.py, 8, INFO, Processing year 2010 for ticker GRF.
# 2026-01-19 23:26:07,264, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2010
# 2026-01-19 23:26:07,270, 2113979629.py, 8, INFO, Processing year 2011 for ticker GRF.
# 2026-01-19 23:26:07,271, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2011
# 2026-01-19 23:26:07,278, 2113979629.py, 8, INFO, Processing year 2012 for ticker GRF.
# 2026-01-19 23:26:07,280, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2012
# 2026-01-19 23:26:07,288, 2113979629.py, 8, INFO, Processing year 2013 for ticker GRF.
# 2026-01-19 23:26:07,290, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2013
# 2026-01-19 23:26:07,297, 2113979629.py, 8, INFO, Processing year 2014 for ticker GRF.
# 2026-01-19 23:26:07,298, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2014
# 2026-01-19 23:26:07,304, 2113979629.py, 8, INFO, Processing year 2015 for ticker GRF.
# 2026-01-19 23:26:07,306, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2015
# 2026-01-19 23:26:07,311, 2113979629.py, 8, INFO, Processing year 2016 for ticker GRF.
# 2026-01-19 23:26:07,313, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2016
# 2026-01-19 23:26:07,323, 2113979629.py, 8, INFO, Processing year 2017 for ticker GRF.
# 2026-01-19 23:26:07,324, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2017
# 2026-01-19 23:26:07,330, 2113979629.py, 8, INFO, Processing year 2018 for ticker GRF.
# 2026-01-19 23:26:07,332, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2018
# 2026-01-19 23:26:07,337, 2113979629.py, 8, INFO, Processing year 2019 for ticker GRF.
# 2026-01-19 23:26:07,339, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2019
# 2026-01-19 23:26:07,347, 2113979629.py, 8, INFO, Processing year 2020 for ticker GRF.
# 2026-01-19 23:26:07,349, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2020
# 2026-01-19 23:26:07,354, 2113979629.py, 4, INFO, Processing ticker: KRC
# 2026-01-19 23:26:07,360, 2113979629.py, 8, INFO, Processing year 1997 for ticker KRC.
# 2026-01-19 23:26:07,365, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1997
# 2026-01-19 23:26:07,371, 2113979629.py, 8, INFO, Processing year 1998 for ticker KRC.
# 2026-01-19 23:26:07,372, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1998
# 2026-01-19 23:26:07,377, 2113979629.py, 8, INFO, Processing year 1999 for ticker KRC.
# 2026-01-19 23:26:07,379, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1999
# 2026-01-19 23:26:07,385, 2113979629.py, 8, INFO, Processing year 2000 for ticker KRC.
# 2026-01-19 23:26:07,387, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2000
# 2026-01-19 23:26:07,393, 2113979629.py, 8, INFO, Processing year 2001 for ticker KRC.
# 2026-01-19 23:26:07,394, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2001
# 2026-01-19 23:26:07,400, 2113979629.py, 8, INFO, Processing year 2002 for ticker KRC.
# 2026-01-19 23:26:07,405, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2002
# 2026-01-19 23:26:07,412, 2113979629.py, 8, INFO, Processing year 2003 for ticker KRC.
# 2026-01-19 23:26:07,414, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2003
# 2026-01-19 23:26:07,419, 2113979629.py, 8, INFO, Processing year 2004 for ticker KRC.
# 2026-01-19 23:26:07,421, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2004
# 2026-01-19 23:26:07,430, 2113979629.py, 8, INFO, Processing year 2005 for ticker KRC.
# 2026-01-19 23:26:07,432, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2005
# 2026-01-19 23:26:07,437, 2113979629.py, 8, INFO, Processing year 2006 for ticker KRC.
# 2026-01-19 23:26:07,439, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2006
# 2026-01-19 23:26:07,444, 2113979629.py, 8, INFO, Processing year 2007 for ticker KRC.
# 2026-01-19 23:26:07,446, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2007
# 2026-01-19 23:26:07,453, 2113979629.py, 8, INFO, Processing year 2008 for ticker KRC.
# 2026-01-19 23:26:07,455, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2008
# 2026-01-19 23:26:07,460, 2113979629.py, 8, INFO, Processing year 2009 for ticker KRC.
# 2026-01-19 23:26:07,461, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2009
# 2026-01-19 23:26:07,466, 2113979629.py, 8, INFO, Processing year 2010 for ticker KRC.
# 2026-01-19 23:26:07,472, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2010
# 2026-01-19 23:26:07,477, 2113979629.py, 8, INFO, Processing year 2011 for ticker KRC.
# 2026-01-19 23:26:07,478, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2011
# 2026-01-19 23:26:07,483, 2113979629.py, 8, INFO, Processing year 2012 for ticker KRC.
# 2026-01-19 23:26:07,485, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2012
# 2026-01-19 23:26:07,494, 2113979629.py, 8, INFO, Processing year 2013 for ticker KRC.
# 2026-01-19 23:26:07,496, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2013
# 2026-01-19 23:26:07,500, 2113979629.py, 8, INFO, Processing year 2014 for ticker KRC.
# 2026-01-19 23:26:07,502, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2014
# 2026-01-19 23:26:07,509, 2113979629.py, 8, INFO, Processing year 2015 for ticker KRC.
# 2026-01-19 23:26:07,511, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2015
# 2026-01-19 23:26:07,516, 2113979629.py, 8, INFO, Processing year 2016 for ticker KRC.
# 2026-01-19 23:26:07,518, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2016
# 2026-01-19 23:26:07,523, 2113979629.py, 8, INFO, Processing year 2017 for ticker KRC.
# 2026-01-19 23:26:07,524, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2017
# 2026-01-19 23:26:07,533, 2113979629.py, 8, INFO, Processing year 2018 for ticker KRC.
# 2026-01-19 23:26:07,535, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2018
# 2026-01-19 23:26:07,540, 2113979629.py, 8, INFO, Processing year 2019 for ticker KRC.
# 2026-01-19 23:26:07,542, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2019
# 2026-01-19 23:26:07,548, 2113979629.py, 8, INFO, Processing year 2020 for ticker KRC.
# 2026-01-19 23:26:07,549, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2020
# 2026-01-19 23:26:07,555, 2113979629.py, 4, INFO, Processing ticker: MICT
# 2026-01-19 23:26:07,561, 2113979629.py, 8, INFO, Processing year 2012 for ticker MICT.
# 2026-01-19 23:26:07,562, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2012
# 2026-01-19 23:26:07,568, 2113979629.py, 8, INFO, Processing year 2013 for ticker MICT.
# 2026-01-19 23:26:07,570, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2013
# 2026-01-19 23:26:07,579, 2113979629.py, 8, INFO, Processing year 2014 for ticker MICT.
# 2026-01-19 23:26:07,581, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2014
# 2026-01-19 23:26:07,586, 2113979629.py, 8, INFO, Processing year 2015 for ticker MICT.
# 2026-01-19 23:26:07,588, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2015
# 2026-01-19 23:26:07,597, 2113979629.py, 8, INFO, Processing year 2016 for ticker MICT.
# 2026-01-19 23:26:07,599, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2016
# 2026-01-19 23:26:07,603, 2113979629.py, 8, INFO, Processing year 2017 for ticker MICT.
# 2026-01-19 23:26:07,605, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2017
# 2026-01-19 23:26:07,612, 2113979629.py, 8, INFO, Processing year 2018 for ticker MICT.
# 2026-01-19 23:26:07,614, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2018
# 2026-01-19 23:26:07,621, 2113979629.py, 8, INFO, Processing year 2019 for ticker MICT.
# 2026-01-19 23:26:07,623, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2019
# 2026-01-19 23:26:07,629, 2113979629.py, 8, INFO, Processing year 2020 for ticker MICT.
# 2026-01-19 23:26:07,630, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2020
# 2026-01-19 23:26:07,635, 2113979629.py, 4, INFO, Processing ticker: AMPY
# 2026-01-19 23:26:07,641, 2113979629.py, 8, INFO, Processing year 2012 for ticker AMPY.
# 2026-01-19 23:26:07,643, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2012
# 2026-01-19 23:26:07,648, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMPY.
# 2026-01-19 23:26:07,650, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2013
# 2026-01-19 23:26:07,658, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMPY.
# 2026-01-19 23:26:07,660, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2014
# 2026-01-19 23:26:07,665, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMPY.
# 2026-01-19 23:26:07,667, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2015
# 2026-01-19 23:26:07,672, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMPY.
# 2026-01-19 23:26:07,674, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2016
# 2026-01-19 23:26:07,682, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMPY.
# 2026-01-19 23:26:07,684, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2017
# 2026-01-19 23:26:07,690, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMPY.
# 2026-01-19 23:26:07,692, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2018
# 2026-01-19 23:26:07,698, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMPY.
# 2026-01-19 23:26:07,699, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2019
# 2026-01-19 23:26:07,708, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMPY.
# 2026-01-19 23:26:07,710, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2020
# 2026-01-19 23:26:07,715, 2113979629.py, 4, INFO, Processing ticker: A
# 2026-01-19 23:26:07,721, 2113979629.py, 8, INFO, Processing year 1999 for ticker A.
# 2026-01-19 23:26:07,726, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_1999
# 2026-01-19 23:26:07,732, 2113979629.py, 8, INFO, Processing year 2000 for ticker A.
# 2026-01-19 23:26:07,733, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2000
# 2026-01-19 23:26:07,739, 2113979629.py, 8, INFO, Processing year 2001 for ticker A.
# 2026-01-19 23:26:07,740, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2001
# 2026-01-19 23:26:07,749, 2113979629.py, 8, INFO, Processing year 2002 for ticker A.
# 2026-01-19 23:26:07,751, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2002
# 2026-01-19 23:26:07,757, 2113979629.py, 8, INFO, Processing year 2003 for ticker A.
# 2026-01-19 23:26:07,758, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2003
# 2026-01-19 23:26:07,764, 2113979629.py, 8, INFO, Processing year 2004 for ticker A.
# 2026-01-19 23:26:07,765, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2004
# 2026-01-19 23:26:07,774, 2113979629.py, 8, INFO, Processing year 2005 for ticker A.
# 2026-01-19 23:26:07,776, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2005
# 2026-01-19 23:26:07,781, 2113979629.py, 8, INFO, Processing year 2006 for ticker A.
# 2026-01-19 23:26:07,783, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2006
# 2026-01-19 23:26:07,790, 2113979629.py, 8, INFO, Processing year 2007 for ticker A.
# 2026-01-19 23:26:07,792, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2007
# 2026-01-19 23:26:07,798, 2113979629.py, 8, INFO, Processing year 2008 for ticker A.
# 2026-01-19 23:26:07,800, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2008
# 2026-01-19 23:26:07,809, 2113979629.py, 8, INFO, Processing year 2009 for ticker A.
# 2026-01-19 23:26:07,811, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2009
# 2026-01-19 23:26:07,820, 2113979629.py, 8, INFO, Processing year 2010 for ticker A.
# 2026-01-19 23:26:07,822, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2010
# 2026-01-19 23:26:07,827, 2113979629.py, 8, INFO, Processing year 2011 for ticker A.
# 2026-01-19 23:26:07,829, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2011
# 2026-01-19 23:26:07,834, 2113979629.py, 8, INFO, Processing year 2012 for ticker A.
# 2026-01-19 23:26:07,836, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2012
# 2026-01-19 23:26:07,841, 2113979629.py, 8, INFO, Processing year 2013 for ticker A.
# 2026-01-19 23:26:07,843, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2013
# 2026-01-19 23:26:07,853, 2113979629.py, 8, INFO, Processing year 2014 for ticker A.
# 2026-01-19 23:26:07,854, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2014
# 2026-01-19 23:26:07,860, 2113979629.py, 8, INFO, Processing year 2015 for ticker A.
# 2026-01-19 23:26:07,862, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2015
# 2026-01-19 23:26:07,868, 2113979629.py, 8, INFO, Processing year 2016 for ticker A.
# 2026-01-19 23:26:07,869, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2016
# 2026-01-19 23:26:07,878, 2113979629.py, 8, INFO, Processing year 2017 for ticker A.
# 2026-01-19 23:26:07,880, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2017
# 2026-01-19 23:26:07,888, 2113979629.py, 8, INFO, Processing year 2018 for ticker A.
# 2026-01-19 23:26:07,890, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2018
# 2026-01-19 23:26:07,901, 2113979629.py, 8, INFO, Processing year 2019 for ticker A.
# 2026-01-19 23:26:07,904, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2019
# 2026-01-19 23:26:07,909, 2113979629.py, 8, INFO, Processing year 2020 for ticker A.
# 2026-01-19 23:26:07,911, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2020
# 2026-01-19 23:26:07,919, 2113979629.py, 4, INFO, Processing ticker: WRLSU
# 2026-01-19 23:26:07,925, 2113979629.py, 8, INFO, Processing year 2017 for ticker WRLSU.
# 2026-01-19 23:26:07,927, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2017
# 2026-01-19 23:26:07,936, 2113979629.py, 8, INFO, Processing year 2018 for ticker WRLSU.
# 2026-01-19 23:26:07,938, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2018
# 2026-01-19 23:26:07,944, 2113979629.py, 8, INFO, Processing year 2019 for ticker WRLSU.
# 2026-01-19 23:26:07,946, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2019
# 2026-01-19 23:26:07,951, 2113979629.py, 8, INFO, Processing year 2020 for ticker WRLSU.
# 2026-01-19 23:26:07,953, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2020
# 2026-01-19 23:26:07,958, 2113979629.py, 4, INFO, Processing ticker: PNR
# 2026-01-19 23:26:07,964, 2113979629.py, 8, INFO, Processing year 1973 for ticker PNR.
# 2026-01-19 23:26:07,965, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1973
# 2026-01-19 23:26:07,971, 2113979629.py, 8, INFO, Processing year 1974 for ticker PNR.
# 2026-01-19 23:26:07,972, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1974
# 2026-01-19 23:26:07,980, 2113979629.py, 8, INFO, Processing year 1975 for ticker PNR.
# 2026-01-19 23:26:07,982, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1975
# 2026-01-19 23:26:07,988, 2113979629.py, 8, INFO, Processing year 1976 for ticker PNR.
# 2026-01-19 23:26:07,989, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1976
# 2026-01-19 23:26:07,995, 2113979629.py, 8, INFO, Processing year 1977 for ticker PNR.
# 2026-01-19 23:26:07,996, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1977
# 2026-01-19 23:26:08,005, 2113979629.py, 8, INFO, Processing year 1978 for ticker PNR.
# 2026-01-19 23:26:08,007, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1978
# 2026-01-19 23:26:08,012, 2113979629.py, 8, INFO, Processing year 1979 for ticker PNR.
# 2026-01-19 23:26:08,014, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1979
# 2026-01-19 23:26:08,023, 2113979629.py, 8, INFO, Processing year 1980 for ticker PNR.
# 2026-01-19 23:26:08,025, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1980
# 2026-01-19 23:26:08,030, 2113979629.py, 8, INFO, Processing year 1981 for ticker PNR.
# 2026-01-19 23:26:08,032, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1981
# 2026-01-19 23:26:08,037, 2113979629.py, 8, INFO, Processing year 1982 for ticker PNR.
# 2026-01-19 23:26:08,039, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1982
# 2026-01-19 23:26:08,049, 2113979629.py, 8, INFO, Processing year 1983 for ticker PNR.
# 2026-01-19 23:26:08,051, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1983
# 2026-01-19 23:26:08,056, 2113979629.py, 8, INFO, Processing year 1984 for ticker PNR.
# 2026-01-19 23:26:08,058, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1984
# 2026-01-19 23:26:08,067, 2113979629.py, 8, INFO, Processing year 1985 for ticker PNR.
# 2026-01-19 23:26:08,069, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1985
# 2026-01-19 23:26:08,074, 2113979629.py, 8, INFO, Processing year 1986 for ticker PNR.
# 2026-01-19 23:26:08,076, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1986
# 2026-01-19 23:26:08,082, 2113979629.py, 8, INFO, Processing year 1987 for ticker PNR.
# 2026-01-19 23:26:08,083, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1987
# 2026-01-19 23:26:08,093, 2113979629.py, 8, INFO, Processing year 1988 for ticker PNR.
# 2026-01-19 23:26:08,095, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1988
# 2026-01-19 23:26:08,100, 2113979629.py, 8, INFO, Processing year 1989 for ticker PNR.
# 2026-01-19 23:26:08,102, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1989
# 2026-01-19 23:26:08,109, 2113979629.py, 8, INFO, Processing year 1990 for ticker PNR.
# 2026-01-19 23:26:08,111, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1990
# 2026-01-19 23:26:08,116, 2113979629.py, 8, INFO, Processing year 1991 for ticker PNR.
# 2026-01-19 23:26:08,118, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1991
# 2026-01-19 23:26:08,125, 2113979629.py, 8, INFO, Processing year 1992 for ticker PNR.
# 2026-01-19 23:26:08,131, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1992
# 2026-01-19 23:26:08,137, 2113979629.py, 8, INFO, Processing year 1993 for ticker PNR.
# 2026-01-19 23:26:08,138, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1993
# 2026-01-19 23:26:08,144, 2113979629.py, 8, INFO, Processing year 1994 for ticker PNR.
# 2026-01-19 23:26:08,146, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1994
# 2026-01-19 23:26:08,153, 2113979629.py, 8, INFO, Processing year 1995 for ticker PNR.
# 2026-01-19 23:26:08,154, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1995
# 2026-01-19 23:26:08,161, 2113979629.py, 8, INFO, Processing year 1996 for ticker PNR.
# 2026-01-19 23:26:08,163, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1996
# 2026-01-19 23:26:08,168, 2113979629.py, 8, INFO, Processing year 1997 for ticker PNR.
# 2026-01-19 23:26:08,170, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1997
# 2026-01-19 23:26:08,175, 2113979629.py, 8, INFO, Processing year 1998 for ticker PNR.
# 2026-01-19 23:26:08,177, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1998
# 2026-01-19 23:26:08,183, 2113979629.py, 8, INFO, Processing year 1999 for ticker PNR.
# 2026-01-19 23:26:08,184, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1999
# 2026-01-19 23:26:08,190, 2113979629.py, 8, INFO, Processing year 2000 for ticker PNR.
# 2026-01-19 23:26:08,192, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2000
# 2026-01-19 23:26:08,200, 2113979629.py, 8, INFO, Processing year 2001 for ticker PNR.
# 2026-01-19 23:26:08,202, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2001
# 2026-01-19 23:26:08,207, 2113979629.py, 8, INFO, Processing year 2002 for ticker PNR.
# 2026-01-19 23:26:08,209, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2002
# 2026-01-19 23:26:08,215, 2113979629.py, 8, INFO, Processing year 2003 for ticker PNR.
# 2026-01-19 23:26:08,217, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2003
# 2026-01-19 23:26:08,226, 2113979629.py, 8, INFO, Processing year 2004 for ticker PNR.
# 2026-01-19 23:26:08,229, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2004
# 2026-01-19 23:26:08,235, 2113979629.py, 8, INFO, Processing year 2005 for ticker PNR.
# 2026-01-19 23:26:08,237, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2005
# 2026-01-19 23:26:08,246, 2113979629.py, 8, INFO, Processing year 2006 for ticker PNR.
# 2026-01-19 23:26:08,248, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2006
# ...
# 2026-01-19 23:26:14,841, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2000
# 2026-01-19 23:26:14,849, 2113979629.py, 8, INFO, Processing year 2001 for ticker AMAT.
# 2026-01-19 23:26:14,851, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2001
# 2026-01-19 23:26:14,856, 2113979629.py, 8, INFO, Processing year 2002 for ticker AMAT.
# 2026-01-19 23:26:14,858, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2002
# 2026-01-19 23:26:14,863, 2113979629.py, 8, INFO, Processing year 2003 for ticker AMAT.
# 2026-01-19 23:26:14,865, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2003
# 2026-01-19 23:26:14,875, 2113979629.py, 8, INFO, Processing year 2004 for ticker AMAT.
# 2026-01-19 23:26:14,877, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2004
# 2026-01-19 23:26:14,885, 2113979629.py, 8, INFO, Processing year 2005 for ticker AMAT.
# 2026-01-19 23:26:14,890, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2005
# 2026-01-19 23:26:14,896, 2113979629.py, 8, INFO, Processing year 2006 for ticker AMAT.
# 2026-01-19 23:26:14,898, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2006
# 2026-01-19 23:26:14,903, 2113979629.py, 8, INFO, Processing year 2007 for ticker AMAT.
# 2026-01-19 23:26:14,905, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2007
# 2026-01-19 23:26:14,913, 2113979629.py, 8, INFO, Processing year 2008 for ticker AMAT.
# 2026-01-19 23:26:14,915, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2008
# 2026-01-19 23:26:14,920, 2113979629.py, 8, INFO, Processing year 2009 for ticker AMAT.
# 2026-01-19 23:26:14,922, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2009
# 2026-01-19 23:26:14,933, 2113979629.py, 8, INFO, Processing year 2010 for ticker AMAT.
# 2026-01-19 23:26:14,935, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2010
# 2026-01-19 23:26:14,940, 2113979629.py, 8, INFO, Processing year 2011 for ticker AMAT.
# 2026-01-19 23:26:14,942, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2011
# 2026-01-19 23:26:14,951, 2113979629.py, 8, INFO, Processing year 2012 for ticker AMAT.
# 2026-01-19 23:26:14,953, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2012
# 2026-01-19 23:26:14,958, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMAT.
# 2026-01-19 23:26:14,960, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2013
# 2026-01-19 23:26:14,969, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMAT.
# 2026-01-19 23:26:14,971, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2014
# 2026-01-19 23:26:14,979, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMAT.
# 2026-01-19 23:26:14,981, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2015
# 2026-01-19 23:26:14,987, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMAT.
# 2026-01-19 23:26:14,988, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2016
# 2026-01-19 23:26:14,994, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMAT.
# 2026-01-19 23:26:14,995, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2017
# 2026-01-19 23:26:15,001, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMAT.
# 2026-01-19 23:26:15,003, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2018
# 2026-01-19 23:26:15,009, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMAT.
# 2026-01-19 23:26:15,010, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2019
# 2026-01-19 23:26:15,016, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMAT.
# 2026-01-19 23:26:15,018, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2020
# 2026-01-19 23:26:15,024, 2113979629.py, 4, INFO, Processing ticker: PSB
# 2026-01-19 23:26:15,030, 2113979629.py, 8, INFO, Processing year 1991 for ticker PSB.
# 2026-01-19 23:26:15,032, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1991
# 2026-01-19 23:26:15,038, 2113979629.py, 8, INFO, Processing year 1992 for ticker PSB.
# 2026-01-19 23:26:15,039, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1992
# 2026-01-19 23:26:15,045, 2113979629.py, 8, INFO, Processing year 1993 for ticker PSB.
# 2026-01-19 23:26:15,047, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1993
# 2026-01-19 23:26:15,057, 2113979629.py, 8, INFO, Processing year 1994 for ticker PSB.
# 2026-01-19 23:26:15,058, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1994
# 2026-01-19 23:26:15,064, 2113979629.py, 8, INFO, Processing year 1995 for ticker PSB.
# 2026-01-19 23:26:15,066, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1995
# 2026-01-19 23:26:15,072, 2113979629.py, 8, INFO, Processing year 1996 for ticker PSB.
# 2026-01-19 23:26:15,074, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1996
# 2026-01-19 23:26:15,083, 2113979629.py, 8, INFO, Processing year 1997 for ticker PSB.
# 2026-01-19 23:26:15,085, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1997
# 2026-01-19 23:26:15,099, 2113979629.py, 8, INFO, Processing year 1998 for ticker PSB.
# 2026-01-19 23:26:15,102, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1998
# 2026-01-19 23:26:15,107, 2113979629.py, 8, INFO, Processing year 1999 for ticker PSB.
# 2026-01-19 23:26:15,109, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1999
# 2026-01-19 23:26:15,113, 2113979629.py, 8, INFO, Processing year 2000 for ticker PSB.
# 2026-01-19 23:26:15,115, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2000
# 2026-01-19 23:26:15,124, 2113979629.py, 8, INFO, Processing year 2001 for ticker PSB.
# 2026-01-19 23:26:15,126, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2001
# 2026-01-19 23:26:15,132, 2113979629.py, 8, INFO, Processing year 2002 for ticker PSB.
# 2026-01-19 23:26:15,134, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2002
# 2026-01-19 23:26:15,144, 2113979629.py, 8, INFO, Processing year 2003 for ticker PSB.
# 2026-01-19 23:26:15,146, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2003
# 2026-01-19 23:26:15,152, 2113979629.py, 8, INFO, Processing year 2004 for ticker PSB.
# 2026-01-19 23:26:15,154, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2004
# 2026-01-19 23:26:15,160, 2113979629.py, 8, INFO, Processing year 2005 for ticker PSB.
# 2026-01-19 23:26:15,161, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2005
# 2026-01-19 23:26:15,170, 2113979629.py, 8, INFO, Processing year 2006 for ticker PSB.
# 2026-01-19 23:26:15,172, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2006
# 2026-01-19 23:26:15,177, 2113979629.py, 8, INFO, Processing year 2007 for ticker PSB.
# 2026-01-19 23:26:15,179, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2007
# 2026-01-19 23:26:15,188, 2113979629.py, 8, INFO, Processing year 2008 for ticker PSB.
# 2026-01-19 23:26:15,190, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2008
# 2026-01-19 23:26:15,195, 2113979629.py, 8, INFO, Processing year 2009 for ticker PSB.
# 2026-01-19 23:26:15,197, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2009
# 2026-01-19 23:26:15,203, 2113979629.py, 8, INFO, Processing year 2010 for ticker PSB.
# 2026-01-19 23:26:15,205, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2010
# 2026-01-19 23:26:15,211, 2113979629.py, 8, INFO, Processing year 2011 for ticker PSB.
# 2026-01-19 23:26:15,212, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2011
# 2026-01-19 23:26:15,222, 2113979629.py, 8, INFO, Processing year 2012 for ticker PSB.
# 2026-01-19 23:26:15,224, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2012
# 2026-01-19 23:26:15,229, 2113979629.py, 8, INFO, Processing year 2013 for ticker PSB.
# 2026-01-19 23:26:15,231, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2013
# 2026-01-19 23:26:15,240, 2113979629.py, 8, INFO, Processing year 2014 for ticker PSB.
# 2026-01-19 23:26:15,242, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2014
# 2026-01-19 23:26:15,248, 2113979629.py, 8, INFO, Processing year 2015 for ticker PSB.
# 2026-01-19 23:26:15,250, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2015
# 2026-01-19 23:26:15,255, 2113979629.py, 8, INFO, Processing year 2016 for ticker PSB.
# 2026-01-19 23:26:15,257, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2016
# 2026-01-19 23:26:15,262, 2113979629.py, 8, INFO, Processing year 2017 for ticker PSB.
# 2026-01-19 23:26:15,263, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2017
# 2026-01-19 23:26:15,269, 2113979629.py, 8, INFO, Processing year 2018 for ticker PSB.
# 2026-01-19 23:26:15,271, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2018
# 2026-01-19 23:26:15,276, 2113979629.py, 8, INFO, Processing year 2019 for ticker PSB.
# 2026-01-19 23:26:15,278, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2019
# 2026-01-19 23:26:15,284, 2113979629.py, 8, INFO, Processing year 2020 for ticker PSB.
# 2026-01-19 23:26:15,285, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2020
# 2026-01-19 23:26:15,294, 2113979629.py, 4, INFO, Processing ticker: CTSO
# 2026-01-19 23:26:15,300, 2113979629.py, 8, INFO, Processing year 2006 for ticker CTSO.
# 2026-01-19 23:26:15,302, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2006
# 2026-01-19 23:26:15,309, 2113979629.py, 8, INFO, Processing year 2007 for ticker CTSO.
# 2026-01-19 23:26:15,311, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2007
# 2026-01-19 23:26:15,316, 2113979629.py, 8, INFO, Processing year 2008 for ticker CTSO.
# 2026-01-19 23:26:15,317, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2008
# 2026-01-19 23:26:15,322, 2113979629.py, 8, INFO, Processing year 2009 for ticker CTSO.
# 2026-01-19 23:26:15,324, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2009
# 2026-01-19 23:26:15,329, 2113979629.py, 8, INFO, Processing year 2010 for ticker CTSO.
# 2026-01-19 23:26:15,331, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2010
# 2026-01-19 23:26:15,337, 2113979629.py, 8, INFO, Processing year 2011 for ticker CTSO.
# 2026-01-19 23:26:15,339, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2011
# 2026-01-19 23:26:15,348, 2113979629.py, 8, INFO, Processing year 2012 for ticker CTSO.
# 2026-01-19 23:26:15,351, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2012
# 2026-01-19 23:26:15,358, 2113979629.py, 8, INFO, Processing year 2013 for ticker CTSO.
# 2026-01-19 23:26:15,361, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2013
# 2026-01-19 23:26:15,370, 2113979629.py, 8, INFO, Processing year 2014 for ticker CTSO.
# 2026-01-19 23:26:15,372, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2014
# 2026-01-19 23:26:15,377, 2113979629.py, 8, INFO, Processing year 2015 for ticker CTSO.
# 2026-01-19 23:26:15,379, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2015
# 2026-01-19 23:26:15,385, 2113979629.py, 8, INFO, Processing year 2016 for ticker CTSO.
# 2026-01-19 23:26:15,387, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2016
# 2026-01-19 23:26:15,392, 2113979629.py, 8, INFO, Processing year 2017 for ticker CTSO.
# 2026-01-19 23:26:15,394, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2017
# 2026-01-19 23:26:15,400, 2113979629.py, 8, INFO, Processing year 2018 for ticker CTSO.
# 2026-01-19 23:26:15,402, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2018
# 2026-01-19 23:26:15,411, 2113979629.py, 8, INFO, Processing year 2019 for ticker CTSO.
# 2026-01-19 23:26:15,412, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2019
# 2026-01-19 23:26:15,418, 2113979629.py, 8, INFO, Processing year 2020 for ticker CTSO.
# 2026-01-19 23:26:15,420, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2020
# 2026-01-19 23:26:15,428, 2113979629.py, 4, INFO, Processing ticker: UEC
# 2026-01-19 23:26:15,434, 2113979629.py, 8, INFO, Processing year 2007 for ticker UEC.
# 2026-01-19 23:26:15,436, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2007
# 2026-01-19 23:26:15,442, 2113979629.py, 8, INFO, Processing year 2008 for ticker UEC.
# 2026-01-19 23:26:15,443, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2008
# 2026-01-19 23:26:15,452, 2113979629.py, 8, INFO, Processing year 2009 for ticker UEC.
# 2026-01-19 23:26:15,454, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2009
# 2026-01-19 23:26:15,461, 2113979629.py, 8, INFO, Processing year 2010 for ticker UEC.
# 2026-01-19 23:26:15,462, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2010
# 2026-01-19 23:26:15,472, 2113979629.py, 8, INFO, Processing year 2011 for ticker UEC.
# 2026-01-19 23:26:15,474, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2011
# 2026-01-19 23:26:15,479, 2113979629.py, 8, INFO, Processing year 2012 for ticker UEC.
# 2026-01-19 23:26:15,481, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2012
# 2026-01-19 23:26:15,487, 2113979629.py, 8, INFO, Processing year 2013 for ticker UEC.
# 2026-01-19 23:26:15,488, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2013
# 2026-01-19 23:26:15,497, 2113979629.py, 8, INFO, Processing year 2014 for ticker UEC.
# 2026-01-19 23:26:15,499, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2014
# 2026-01-19 23:26:15,504, 2113979629.py, 8, INFO, Processing year 2015 for ticker UEC.
# 2026-01-19 23:26:15,506, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2015
# 2026-01-19 23:26:15,516, 2113979629.py, 8, INFO, Processing year 2016 for ticker UEC.
# 2026-01-19 23:26:15,518, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2016
# 2026-01-19 23:26:15,524, 2113979629.py, 8, INFO, Processing year 2017 for ticker UEC.
# 2026-01-19 23:26:15,526, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2017
# 2026-01-19 23:26:15,535, 2113979629.py, 8, INFO, Processing year 2018 for ticker UEC.
# 2026-01-19 23:26:15,537, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2018
# 2026-01-19 23:26:15,546, 2113979629.py, 8, INFO, Processing year 2019 for ticker UEC.
# 2026-01-19 23:26:15,548, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2019
# 2026-01-19 23:26:15,553, 2113979629.py, 8, INFO, Processing year 2020 for ticker UEC.
# 2026-01-19 23:26:15,555, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2020

# %% [markdown]
# Why would we want to store data this way?
#
# + Data files are easier to maintain. We do not update old data, only recent data or the most recent "delta".
# + Parquet files, as long as they maintain a consistent schema, can all be read jointly.

# %% [markdown]
# # Load, Transform, and Save
#
# In this section, we will load the Parquet files we generated, transform the data, and save the resulting dataset.

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to obtain the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
_logs.info(f'Found {len(parquet_files)} parquet files for reading back into Dask.')

dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# 2026-01-19 23:29:49,044, 174194153.py, 4, INFO, Found 2010 parquet files for reading back into Dask.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work similarly to Pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.
#
# In the code below, the following operation occurs:
#
# + Start with a Dask dataframe, `dd_px`.
# + Group the rows of this dataframe by the variable `ticker`, i.e., each group will contain the observations that pertain only to one ticker at a time. The `group_key` parameter controls whether an index entry is added with the value of the grouping variable (`ticker` in this case); if we made `group_keys=True`, we would have a duplicate `ticker` column.
# + For each group defined by a `ticker`, `apply()` the following calculation:
#
#     - Sort the values by `Date` in ascending order.
#     - Assign a new variable called `Close_lag_1` by shifting the position of the closing price (`Close`) by one position.
#     - Define the schema of the resulting dataframe. If we omit this specification, we would get a warning; however, the simplicity of the calculation ensures that Dask can determine the resulting schema.

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# A               datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32
# ACB                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: setindex, 2 expressions
# Expr=SetIndex(frame=ReadParquetFSSpec(a2331b8), _other='ticker', options={})

# %%
dd_shift = (
    dd_px
        .groupby('ticker', group_keys=False)
        .apply(
            lambda x: x.sort_values('Date', ascending = True)
                       .assign(Close_lag_1 = x['Close'].shift(1)), 
            meta = pd.DataFrame(data ={'Date': 'datetime64[ns]',
                    'Open': 'f8',
                    'High': 'f8',
                    'Low': 'f8',
                    'Close': 'f8',
                    'Adj Close': 'f8',
                    'Volume': 'i8',
                    'source': 'object',
                    'Year': 'int32',
                    'Close_lag_1': 'f8'},
                    index = pd.Index([], dtype=pd.StringDtype(), name='ticker'))
    ))

# %% [markdown]
# Finally, using the dataframe that we created above, we can now `assign` the `Returns` variable to the entire dataset.

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# Question: How do we know that we are not (erroneously) combining the last price of a ticker with the first price of the next ticker?

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# A               object  object  object  object  object    object  object  object  object      object  object
# ACB                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(a2331b8), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x11e6d8a40>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until the computation is required.
# + To trigger an execution in dask use `.compute()` or execute a command that requires the actual values (for example, write to Parquet or SQL).

# %%
dd_rets.compute()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# ticker
# A      1999-11-18  32.546494  35.765381  28.612303  31.473534  27.068665
# A      1999-11-19  30.713520  30.758226  28.478184  28.880543  24.838577
# A      1999-11-22  29.551144  31.473534  28.657009  31.473534  27.068665
# A      1999-11-23  30.400572  31.205294  28.612303  28.612303  24.607880
# A      1999-11-24  28.701717  29.998211  28.612303  29.372318  25.261524
# ...           ...        ...        ...        ...        ...        ...
# ZEUS   2020-03-26   9.610000   9.940000   9.260000   9.590000   9.590000
# ZEUS   2020-03-27   9.330000   9.330000   8.700000   8.700000   8.700000
# ZEUS   2020-03-30   8.810000   9.760000   8.700000   9.680000   9.680000
# ZEUS   2020-03-31   9.640000  10.470000   9.590000  10.350000  10.350000
# ZEUS   2020-04-01  10.140000  10.340000   9.310000   9.470000   9.470000
#
#             Volume    source  Year  Close_lag_1   Returns
# ticker
# A       62546300.0     A.csv  1999          NaN       NaN
# A       15234100.0     A.csv  1999    31.473534 -0.082386
# A        6577800.0     A.csv  1999    28.880543  0.089783
# A        5975600.0     A.csv  1999    31.473534 -0.090909
# A        4843200.0     A.csv  1999    28.612303  0.026563
# ...            ...       ...   ...          ...       ...
# ZEUS       60500.0  ZEUS.csv  2020     9.670000 -0.008273
# ZEUS       52900.0  ZEUS.csv  2020     9.590000 -0.092805
# ZEUS       73700.0  ZEUS.csv  2020     8.700000  0.112644
# ZEUS       68900.0  ZEUS.csv  2020     9.680000  0.069215
# ZEUS       34000.0  ZEUS.csv  2020    10.350000 -0.085024
#
# [230273 rows x 11 columns]

# %%
df = dd_rets.compute()
df.to_csv("test.csv")

# %%
df.head()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# ticker
# A      1999-11-18  32.546494  35.765381  28.612303  31.473534  27.068665
# A      1999-11-19  30.713520  30.758226  28.478184  28.880543  24.838577
# A      1999-11-22  29.551144  31.473534  28.657009  31.473534  27.068665
# A      1999-11-23  30.400572  31.205294  28.612303  28.612303  24.607880
# A      1999-11-24  28.701717  29.998211  28.612303  29.372318  25.261524
#
#             Volume source  Year  Close_lag_1   Returns
# ticker
# A       62546300.0  A.csv  1999          NaN       NaN
# A       15234100.0  A.csv  1999    31.473534 -0.082386
# A        6577800.0  A.csv  1999    28.880543  0.089783
# A        5975600.0  A.csv  1999    31.473534 -0.090909
# A        4843200.0  A.csv  1999    28.612303  0.026563

# %% [markdown]
# ## Save
#
# With our transformed data, we can now save the new feature to a Parquet file. We will need to answer the following questions depending on our context, setup, and available resources:
#
# + Should we keep the same namespace?
# + Should we save all columns?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# A               object  object  object  object  object    object  object  object  object      object  object
# ACB                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(a2331b8), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x11e6d8a40>, args=(), kwargs={})))

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, 
                   overwrite = True, 
                   schema={
                       'Date': 'timestamp[ns]',
                       'Open': 'float64',
                       'High': 'float64',
                       'Low': 'float64',
                       'Close': 'float64',
                       'Adj Close': 'float64',
                       'Volume': 'int64',
                       'source': 'string',
                       'Year': 'int32',
                       'Close_lag_1': 'float64',
                       'Returns': 'float64',
                       'ticker': 'large_string'
                   })

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2026-01-19 23:39:52,014, data_manager.py, 53, INFO, Processing sample of tickers
# 2026-01-19 23:39:52,015, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2026-01-19 23:39:52,035, data_manager.py, 66, INFO, Found 8050 files in ../../05_src/data/prices/
# 2026-01-19 23:39:52,035, data_manager.py, 74, INFO, Selecting sample of files
# 2026-01-19 23:39:52,036, data_manager.py, 80, INFO, Selected 30 files
# 2026-01-19 23:39:52,036, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/SQNS.csv
# 2026-01-19 23:39:52,036, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SQNS.csv
# 2026-01-19 23:39:52,040, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:52,041, data_manager.py, 103, INFO, Processing ticker: SQNS
# 2026-01-19 23:39:52,042, data_manager.py, 107, INFO, Processing year 2011 for ticker SQNS.
# 2026-01-19 23:39:52,045, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2011
# 2026-01-19 23:39:52,053, data_manager.py, 107, INFO, Processing year 2012 for ticker SQNS.
# 2026-01-19 23:39:52,055, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2012
# 2026-01-19 23:39:52,063, data_manager.py, 107, INFO, Processing year 2013 for ticker SQNS.
# 2026-01-19 23:39:52,065, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2013
# 2026-01-19 23:39:52,071, data_manager.py, 107, INFO, Processing year 2014 for ticker SQNS.
# 2026-01-19 23:39:52,072, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2014
# 2026-01-19 23:39:52,079, data_manager.py, 107, INFO, Processing year 2015 for ticker SQNS.
# 2026-01-19 23:39:52,080, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2015
# 2026-01-19 23:39:52,085, data_manager.py, 107, INFO, Processing year 2016 for ticker SQNS.
# 2026-01-19 23:39:52,087, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2016
# 2026-01-19 23:39:52,093, data_manager.py, 107, INFO, Processing year 2017 for ticker SQNS.
# 2026-01-19 23:39:52,094, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2017
# 2026-01-19 23:39:52,099, data_manager.py, 107, INFO, Processing year 2018 for ticker SQNS.
# 2026-01-19 23:39:52,100, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2018
# 2026-01-19 23:39:52,105, data_manager.py, 107, INFO, Processing year 2019 for ticker SQNS.
# 2026-01-19 23:39:52,107, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2019
# 2026-01-19 23:39:52,112, data_manager.py, 107, INFO, Processing year 2020 for ticker SQNS.
# 2026-01-19 23:39:52,116, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SQNS/SQNS_2020
# 2026-01-19 23:39:52,122, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/FBK.csv
# 2026-01-19 23:39:52,123, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FBK.csv
# 2026-01-19 23:39:52,125, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:52,125, data_manager.py, 103, INFO, Processing ticker: FBK
# 2026-01-19 23:39:52,126, data_manager.py, 107, INFO, Processing year 2014 for ticker FBK.
# 2026-01-19 23:39:52,128, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FBK/FBK_2014
# 2026-01-19 23:39:52,134, data_manager.py, 107, INFO, Processing year 2016 for ticker FBK.
# 2026-01-19 23:39:52,136, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FBK/FBK_2016
# 2026-01-19 23:39:52,141, data_manager.py, 107, INFO, Processing year 2017 for ticker FBK.
# 2026-01-19 23:39:52,143, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FBK/FBK_2017
# 2026-01-19 23:39:52,148, data_manager.py, 107, INFO, Processing year 2018 for ticker FBK.
# 2026-01-19 23:39:52,149, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FBK/FBK_2018
# 2026-01-19 23:39:52,154, data_manager.py, 107, INFO, Processing year 2019 for ticker FBK.
# 2026-01-19 23:39:52,155, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FBK/FBK_2019
# 2026-01-19 23:39:52,164, data_manager.py, 107, INFO, Processing year 2020 for ticker FBK.
# 2026-01-19 23:39:52,165, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FBK/FBK_2020
# 2026-01-19 23:39:52,175, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/SPYG.csv
# 2026-01-19 23:39:52,175, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/etfs/SPYG.csv
# 2026-01-19 23:39:52,179, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:52,179, data_manager.py, 103, INFO, Processing ticker: SPYG
# 2026-01-19 23:39:52,180, data_manager.py, 107, INFO, Processing year 2000 for ticker SPYG.
# 2026-01-19 23:39:52,182, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2000
# 2026-01-19 23:39:52,187, data_manager.py, 107, INFO, Processing year 2001 for ticker SPYG.
# 2026-01-19 23:39:52,189, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2001
# 2026-01-19 23:39:52,198, data_manager.py, 107, INFO, Processing year 2002 for ticker SPYG.
# 2026-01-19 23:39:52,199, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2002
# 2026-01-19 23:39:52,205, data_manager.py, 107, INFO, Processing year 2003 for ticker SPYG.
# 2026-01-19 23:39:52,206, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2003
# 2026-01-19 23:39:52,212, data_manager.py, 107, INFO, Processing year 2004 for ticker SPYG.
# 2026-01-19 23:39:52,217, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2004
# 2026-01-19 23:39:52,223, data_manager.py, 107, INFO, Processing year 2005 for ticker SPYG.
# 2026-01-19 23:39:52,224, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2005
# 2026-01-19 23:39:52,233, data_manager.py, 107, INFO, Processing year 2006 for ticker SPYG.
# 2026-01-19 23:39:52,235, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2006
# 2026-01-19 23:39:52,245, data_manager.py, 107, INFO, Processing year 2007 for ticker SPYG.
# 2026-01-19 23:39:52,246, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2007
# 2026-01-19 23:39:52,252, data_manager.py, 107, INFO, Processing year 2008 for ticker SPYG.
# 2026-01-19 23:39:52,254, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2008
# 2026-01-19 23:39:52,260, data_manager.py, 107, INFO, Processing year 2009 for ticker SPYG.
# 2026-01-19 23:39:52,262, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2009
# 2026-01-19 23:39:52,267, data_manager.py, 107, INFO, Processing year 2010 for ticker SPYG.
# 2026-01-19 23:39:52,269, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2010
# 2026-01-19 23:39:52,278, data_manager.py, 107, INFO, Processing year 2011 for ticker SPYG.
# 2026-01-19 23:39:52,280, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2011
# 2026-01-19 23:39:52,286, data_manager.py, 107, INFO, Processing year 2012 for ticker SPYG.
# 2026-01-19 23:39:52,287, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2012
# 2026-01-19 23:39:52,296, data_manager.py, 107, INFO, Processing year 2013 for ticker SPYG.
# 2026-01-19 23:39:52,298, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2013
# 2026-01-19 23:39:52,304, data_manager.py, 107, INFO, Processing year 2014 for ticker SPYG.
# 2026-01-19 23:39:52,306, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2014
# 2026-01-19 23:39:52,316, data_manager.py, 107, INFO, Processing year 2015 for ticker SPYG.
# 2026-01-19 23:39:52,323, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2015
# 2026-01-19 23:39:52,328, data_manager.py, 107, INFO, Processing year 2016 for ticker SPYG.
# 2026-01-19 23:39:52,330, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2016
# 2026-01-19 23:39:52,339, data_manager.py, 107, INFO, Processing year 2017 for ticker SPYG.
# 2026-01-19 23:39:52,341, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2017
# 2026-01-19 23:39:52,350, data_manager.py, 107, INFO, Processing year 2018 for ticker SPYG.
# 2026-01-19 23:39:52,352, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2018
# 2026-01-19 23:39:52,358, data_manager.py, 107, INFO, Processing year 2019 for ticker SPYG.
# 2026-01-19 23:39:52,360, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2019
# 2026-01-19 23:39:52,366, data_manager.py, 107, INFO, Processing year 2020 for ticker SPYG.
# 2026-01-19 23:39:52,368, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SPYG/SPYG_2020
# 2026-01-19 23:39:52,373, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/DJCB.csv
# 2026-01-19 23:39:52,374, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/etfs/DJCB.csv
# 2026-01-19 23:39:52,375, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:52,376, data_manager.py, 103, INFO, Processing ticker: DJCB
# 2026-01-19 23:39:52,376, data_manager.py, 107, INFO, Processing year 2019 for ticker DJCB.
# 2026-01-19 23:39:52,381, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DJCB/DJCB_2019
# 2026-01-19 23:39:52,387, data_manager.py, 107, INFO, Processing year 2020 for ticker DJCB.
# 2026-01-19 23:39:52,389, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DJCB/DJCB_2020
# 2026-01-19 23:39:52,395, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/CZWI.csv
# 2026-01-19 23:39:52,400, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CZWI.csv
# 2026-01-19 23:39:52,403, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:52,404, data_manager.py, 103, INFO, Processing ticker: CZWI
# 2026-01-19 23:39:52,405, data_manager.py, 107, INFO, Processing year 2004 for ticker CZWI.
# 2026-01-19 23:39:52,409, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2004
# 2026-01-19 23:39:52,415, data_manager.py, 107, INFO, Processing year 2005 for ticker CZWI.
# 2026-01-19 23:39:52,417, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2005
# 2026-01-19 23:39:52,425, data_manager.py, 107, INFO, Processing year 2006 for ticker CZWI.
# 2026-01-19 23:39:52,426, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2006
# 2026-01-19 23:39:52,432, data_manager.py, 107, INFO, Processing year 2007 for ticker CZWI.
# 2026-01-19 23:39:52,434, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2007
# 2026-01-19 23:39:52,442, data_manager.py, 107, INFO, Processing year 2008 for ticker CZWI.
# 2026-01-19 23:39:52,443, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2008
# 2026-01-19 23:39:52,449, data_manager.py, 107, INFO, Processing year 2009 for ticker CZWI.
# 2026-01-19 23:39:52,450, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2009
# 2026-01-19 23:39:52,458, data_manager.py, 107, INFO, Processing year 2010 for ticker CZWI.
# 2026-01-19 23:39:52,459, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2010
# 2026-01-19 23:39:52,466, data_manager.py, 107, INFO, Processing year 2011 for ticker CZWI.
# 2026-01-19 23:39:52,468, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2011
# 2026-01-19 23:39:52,476, data_manager.py, 107, INFO, Processing year 2012 for ticker CZWI.
# 2026-01-19 23:39:52,478, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2012
# 2026-01-19 23:39:52,485, data_manager.py, 107, INFO, Processing year 2013 for ticker CZWI.
# 2026-01-19 23:39:52,487, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2013
# 2026-01-19 23:39:52,493, data_manager.py, 107, INFO, Processing year 2014 for ticker CZWI.
# 2026-01-19 23:39:52,495, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2014
# 2026-01-19 23:39:52,503, data_manager.py, 107, INFO, Processing year 2015 for ticker CZWI.
# 2026-01-19 23:39:52,505, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2015
# 2026-01-19 23:39:52,514, data_manager.py, 107, INFO, Processing year 2016 for ticker CZWI.
# 2026-01-19 23:39:52,516, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2016
# 2026-01-19 23:39:52,526, data_manager.py, 107, INFO, Processing year 2017 for ticker CZWI.
# 2026-01-19 23:39:52,528, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2017
# 2026-01-19 23:39:52,537, data_manager.py, 107, INFO, Processing year 2018 for ticker CZWI.
# 2026-01-19 23:39:52,539, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2018
# 2026-01-19 23:39:52,545, data_manager.py, 107, INFO, Processing year 2019 for ticker CZWI.
# 2026-01-19 23:39:52,547, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2019
# 2026-01-19 23:39:52,556, data_manager.py, 107, INFO, Processing year 2020 for ticker CZWI.
# 2026-01-19 23:39:52,558, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CZWI/CZWI_2020
# 2026-01-19 23:39:52,564, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/SOXS.csv
# 2026-01-19 23:39:52,564, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/etfs/SOXS.csv
# 2026-01-19 23:39:52,566, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:52,569, data_manager.py, 103, INFO, Processing ticker: SOXS
# 2026-01-19 23:39:52,570, data_manager.py, 107, INFO, Processing year 2010 for ticker SOXS.
# 2026-01-19 23:39:52,572, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2010
# 2026-01-19 23:39:52,578, data_manager.py, 107, INFO, Processing year 2011 for ticker SOXS.
# 2026-01-19 23:39:52,580, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2011
# 2026-01-19 23:39:52,585, data_manager.py, 107, INFO, Processing year 2012 for ticker SOXS.
# 2026-01-19 23:39:52,587, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2012
# 2026-01-19 23:39:52,593, data_manager.py, 107, INFO, Processing year 2013 for ticker SOXS.
# 2026-01-19 23:39:52,595, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2013
# 2026-01-19 23:39:52,601, data_manager.py, 107, INFO, Processing year 2014 for ticker SOXS.
# 2026-01-19 23:39:52,602, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2014
# 2026-01-19 23:39:52,609, data_manager.py, 107, INFO, Processing year 2015 for ticker SOXS.
# 2026-01-19 23:39:52,610, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2015
# 2026-01-19 23:39:52,616, data_manager.py, 107, INFO, Processing year 2016 for ticker SOXS.
# 2026-01-19 23:39:52,618, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2016
# 2026-01-19 23:39:52,623, data_manager.py, 107, INFO, Processing year 2017 for ticker SOXS.
# 2026-01-19 23:39:52,625, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2017
# 2026-01-19 23:39:52,631, data_manager.py, 107, INFO, Processing year 2018 for ticker SOXS.
# 2026-01-19 23:39:52,632, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2018
# 2026-01-19 23:39:52,638, data_manager.py, 107, INFO, Processing year 2019 for ticker SOXS.
# 2026-01-19 23:39:52,640, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2019
# 2026-01-19 23:39:52,646, data_manager.py, 107, INFO, Processing year 2020 for ticker SOXS.
# 2026-01-19 23:39:52,648, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SOXS/SOXS_2020
# 2026-01-19 23:39:52,654, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/FLIR.csv
# 2026-01-19 23:39:52,654, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FLIR.csv
# 2026-01-19 23:39:52,659, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:52,660, data_manager.py, 103, INFO, Processing ticker: FLIR
# 2026-01-19 23:39:52,661, data_manager.py, 107, INFO, Processing year 1993 for ticker FLIR.
# 2026-01-19 23:39:52,663, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_1993
# 2026-01-19 23:39:52,673, data_manager.py, 107, INFO, Processing year 1994 for ticker FLIR.
# 2026-01-19 23:39:52,674, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_1994
# 2026-01-19 23:39:52,680, data_manager.py, 107, INFO, Processing year 1995 for ticker FLIR.
# 2026-01-19 23:39:52,682, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_1995
# 2026-01-19 23:39:52,687, data_manager.py, 107, INFO, Processing year 1996 for ticker FLIR.
# 2026-01-19 23:39:52,689, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_1996
# 2026-01-19 23:39:52,699, data_manager.py, 107, INFO, Processing year 1997 for ticker FLIR.
# 2026-01-19 23:39:52,701, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_1997
# 2026-01-19 23:39:52,707, data_manager.py, 107, INFO, Processing year 1998 for ticker FLIR.
# 2026-01-19 23:39:52,709, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_1998
# 2026-01-19 23:39:52,715, data_manager.py, 107, INFO, Processing year 1999 for ticker FLIR.
# 2026-01-19 23:39:52,716, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_1999
# 2026-01-19 23:39:52,726, data_manager.py, 107, INFO, Processing year 2000 for ticker FLIR.
# 2026-01-19 23:39:52,728, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2000
# 2026-01-19 23:39:52,734, data_manager.py, 107, INFO, Processing year 2001 for ticker FLIR.
# 2026-01-19 23:39:52,735, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2001
# 2026-01-19 23:39:52,741, data_manager.py, 107, INFO, Processing year 2002 for ticker FLIR.
# 2026-01-19 23:39:52,743, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2002
# 2026-01-19 23:39:52,753, data_manager.py, 107, INFO, Processing year 2003 for ticker FLIR.
# 2026-01-19 23:39:52,755, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2003
# 2026-01-19 23:39:52,760, data_manager.py, 107, INFO, Processing year 2004 for ticker FLIR.
# 2026-01-19 23:39:52,762, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2004
# 2026-01-19 23:39:52,772, data_manager.py, 107, INFO, Processing year 2005 for ticker FLIR.
# 2026-01-19 23:39:52,774, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2005
# 2026-01-19 23:39:52,800, data_manager.py, 107, INFO, Processing year 2006 for ticker FLIR.
# 2026-01-19 23:39:52,802, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2006
# 2026-01-19 23:39:52,809, data_manager.py, 107, INFO, Processing year 2007 for ticker FLIR.
# 2026-01-19 23:39:52,811, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2007
# 2026-01-19 23:39:52,817, data_manager.py, 107, INFO, Processing year 2008 for ticker FLIR.
# 2026-01-19 23:39:52,818, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2008
# 2026-01-19 23:39:52,824, data_manager.py, 107, INFO, Processing year 2009 for ticker FLIR.
# 2026-01-19 23:39:52,826, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2009
# 2026-01-19 23:39:52,834, data_manager.py, 107, INFO, Processing year 2010 for ticker FLIR.
# 2026-01-19 23:39:52,836, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2010
# 2026-01-19 23:39:52,842, data_manager.py, 107, INFO, Processing year 2011 for ticker FLIR.
# 2026-01-19 23:39:52,844, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2011
# 2026-01-19 23:39:52,851, data_manager.py, 107, INFO, Processing year 2012 for ticker FLIR.
# 2026-01-19 23:39:52,853, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2012
# 2026-01-19 23:39:52,859, data_manager.py, 107, INFO, Processing year 2013 for ticker FLIR.
# 2026-01-19 23:39:52,861, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2013
# 2026-01-19 23:39:52,867, data_manager.py, 107, INFO, Processing year 2014 for ticker FLIR.
# 2026-01-19 23:39:52,869, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2014
# 2026-01-19 23:39:52,875, data_manager.py, 107, INFO, Processing year 2015 for ticker FLIR.
# 2026-01-19 23:39:52,876, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2015
# 2026-01-19 23:39:52,886, data_manager.py, 107, INFO, Processing year 2016 for ticker FLIR.
# 2026-01-19 23:39:52,888, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2016
# 2026-01-19 23:39:52,894, data_manager.py, 107, INFO, Processing year 2017 for ticker FLIR.
# 2026-01-19 23:39:52,896, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2017
# 2026-01-19 23:39:52,906, data_manager.py, 107, INFO, Processing year 2018 for ticker FLIR.
# 2026-01-19 23:39:52,908, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2018
# 2026-01-19 23:39:52,915, data_manager.py, 107, INFO, Processing year 2019 for ticker FLIR.
# 2026-01-19 23:39:52,917, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2019
# 2026-01-19 23:39:52,923, data_manager.py, 107, INFO, Processing year 2020 for ticker FLIR.
# 2026-01-19 23:39:52,924, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FLIR/FLIR_2020
# 2026-01-19 23:39:52,930, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/DNKN.csv
# 2026-01-19 23:39:52,930, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DNKN.csv
# 2026-01-19 23:39:52,932, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:52,932, data_manager.py, 103, INFO, Processing ticker: DNKN
# 2026-01-19 23:39:52,933, data_manager.py, 107, INFO, Processing year 2011 for ticker DNKN.
# 2026-01-19 23:39:52,935, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2011
# 2026-01-19 23:39:52,940, data_manager.py, 107, INFO, Processing year 2012 for ticker DNKN.
# 2026-01-19 23:39:52,942, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2012
# 2026-01-19 23:39:52,951, data_manager.py, 107, INFO, Processing year 2013 for ticker DNKN.
# 2026-01-19 23:39:52,953, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2013
# 2026-01-19 23:39:52,959, data_manager.py, 107, INFO, Processing year 2014 for ticker DNKN.
# 2026-01-19 23:39:52,960, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2014
# 2026-01-19 23:39:52,967, data_manager.py, 107, INFO, Processing year 2015 for ticker DNKN.
# 2026-01-19 23:39:52,969, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2015
# 2026-01-19 23:39:52,975, data_manager.py, 107, INFO, Processing year 2016 for ticker DNKN.
# 2026-01-19 23:39:52,976, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2016
# 2026-01-19 23:39:52,982, data_manager.py, 107, INFO, Processing year 2017 for ticker DNKN.
# 2026-01-19 23:39:52,984, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2017
# 2026-01-19 23:39:52,993, data_manager.py, 107, INFO, Processing year 2018 for ticker DNKN.
# 2026-01-19 23:39:52,994, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2018
# 2026-01-19 23:39:53,000, data_manager.py, 107, INFO, Processing year 2019 for ticker DNKN.
# 2026-01-19 23:39:53,001, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2019
# 2026-01-19 23:39:53,011, data_manager.py, 107, INFO, Processing year 2020 for ticker DNKN.
# 2026-01-19 23:39:53,016, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/DNKN/DNKN_2020
# 2026-01-19 23:39:53,022, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/BSTZ.csv
# 2026-01-19 23:39:53,022, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BSTZ.csv
# 2026-01-19 23:39:53,023, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:53,024, data_manager.py, 103, INFO, Processing ticker: BSTZ
# 2026-01-19 23:39:53,024, data_manager.py, 107, INFO, Processing year 2019 for ticker BSTZ.
# 2026-01-19 23:39:53,026, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BSTZ/BSTZ_2019
# 2026-01-19 23:39:53,031, data_manager.py, 107, INFO, Processing year 2020 for ticker BSTZ.
# 2026-01-19 23:39:53,032, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BSTZ/BSTZ_2020
# 2026-01-19 23:39:53,038, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/LTC.csv
# 2026-01-19 23:39:53,038, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LTC.csv
# 2026-01-19 23:39:53,042, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:53,044, data_manager.py, 103, INFO, Processing ticker: LTC
# 2026-01-19 23:39:53,045, data_manager.py, 107, INFO, Processing year 1992 for ticker LTC.
# 2026-01-19 23:39:53,047, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_1992
# 2026-01-19 23:39:53,052, data_manager.py, 107, INFO, Processing year 1993 for ticker LTC.
# 2026-01-19 23:39:53,054, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_1993
# 2026-01-19 23:39:53,060, data_manager.py, 107, INFO, Processing year 1994 for ticker LTC.
# 2026-01-19 23:39:53,062, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_1994
# 2026-01-19 23:39:53,070, data_manager.py, 107, INFO, Processing year 1995 for ticker LTC.
# 2026-01-19 23:39:53,072, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_1995
# 2026-01-19 23:39:53,078, data_manager.py, 107, INFO, Processing year 1996 for ticker LTC.
# 2026-01-19 23:39:53,079, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_1996
# 2026-01-19 23:39:53,088, data_manager.py, 107, INFO, Processing year 1997 for ticker LTC.
# 2026-01-19 23:39:53,089, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_1997
# 2026-01-19 23:39:53,095, data_manager.py, 107, INFO, Processing year 1998 for ticker LTC.
# 2026-01-19 23:39:53,096, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_1998
# 2026-01-19 23:39:53,103, data_manager.py, 107, INFO, Processing year 1999 for ticker LTC.
# 2026-01-19 23:39:53,105, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_1999
# 2026-01-19 23:39:53,114, data_manager.py, 107, INFO, Processing year 2000 for ticker LTC.
# 2026-01-19 23:39:53,116, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2000
# 2026-01-19 23:39:53,122, data_manager.py, 107, INFO, Processing year 2001 for ticker LTC.
# 2026-01-19 23:39:53,123, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2001
# 2026-01-19 23:39:53,129, data_manager.py, 107, INFO, Processing year 2002 for ticker LTC.
# 2026-01-19 23:39:53,130, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2002
# 2026-01-19 23:39:53,135, data_manager.py, 107, INFO, Processing year 2003 for ticker LTC.
# 2026-01-19 23:39:53,137, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2003
# 2026-01-19 23:39:53,145, data_manager.py, 107, INFO, Processing year 2004 for ticker LTC.
# 2026-01-19 23:39:53,147, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2004
# 2026-01-19 23:39:53,153, data_manager.py, 107, INFO, Processing year 2005 for ticker LTC.
# 2026-01-19 23:39:53,154, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2005
# 2026-01-19 23:39:53,162, data_manager.py, 107, INFO, Processing year 2006 for ticker LTC.
# 2026-01-19 23:39:53,164, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2006
# 2026-01-19 23:39:53,171, data_manager.py, 107, INFO, Processing year 2007 for ticker LTC.
# 2026-01-19 23:39:53,173, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2007
# 2026-01-19 23:39:53,180, data_manager.py, 107, INFO, Processing year 2008 for ticker LTC.
# 2026-01-19 23:39:53,182, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2008
# 2026-01-19 23:39:53,190, data_manager.py, 107, INFO, Processing year 2009 for ticker LTC.
# 2026-01-19 23:39:53,192, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2009
# 2026-01-19 23:39:53,198, data_manager.py, 107, INFO, Processing year 2010 for ticker LTC.
# 2026-01-19 23:39:53,199, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2010
# 2026-01-19 23:39:53,205, data_manager.py, 107, INFO, Processing year 2011 for ticker LTC.
# 2026-01-19 23:39:53,207, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2011
# 2026-01-19 23:39:53,216, data_manager.py, 107, INFO, Processing year 2012 for ticker LTC.
# 2026-01-19 23:39:53,218, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2012
# 2026-01-19 23:39:53,223, data_manager.py, 107, INFO, Processing year 2013 for ticker LTC.
# 2026-01-19 23:39:53,224, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2013
# 2026-01-19 23:39:53,231, data_manager.py, 107, INFO, Processing year 2014 for ticker LTC.
# 2026-01-19 23:39:53,233, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2014
# 2026-01-19 23:39:53,238, data_manager.py, 107, INFO, Processing year 2015 for ticker LTC.
# 2026-01-19 23:39:53,240, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2015
# 2026-01-19 23:39:53,254, data_manager.py, 107, INFO, Processing year 2016 for ticker LTC.
# 2026-01-19 23:39:53,256, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2016
# 2026-01-19 23:39:53,262, data_manager.py, 107, INFO, Processing year 2017 for ticker LTC.
# 2026-01-19 23:39:53,263, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2017
# 2026-01-19 23:39:53,273, data_manager.py, 107, INFO, Processing year 2018 for ticker LTC.
# 2026-01-19 23:39:53,275, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2018
# 2026-01-19 23:39:53,280, data_manager.py, 107, INFO, Processing year 2019 for ticker LTC.
# 2026-01-19 23:39:53,282, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2019
# 2026-01-19 23:39:53,288, data_manager.py, 107, INFO, Processing year 2020 for ticker LTC.
# 2026-01-19 23:39:53,290, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/LTC/LTC_2020
# 2026-01-19 23:39:53,298, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/SWM.csv
# 2026-01-19 23:39:53,298, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SWM.csv
# 2026-01-19 23:39:53,302, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:53,302, data_manager.py, 103, INFO, Processing ticker: SWM
# 2026-01-19 23:39:53,304, data_manager.py, 107, INFO, Processing year 1995 for ticker SWM.
# 2026-01-19 23:39:53,305, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_1995
# 2026-01-19 23:39:53,318, data_manager.py, 107, INFO, Processing year 1996 for ticker SWM.
# 2026-01-19 23:39:53,320, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_1996
# 2026-01-19 23:39:53,326, data_manager.py, 107, INFO, Processing year 1997 for ticker SWM.
# 2026-01-19 23:39:53,327, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_1997
# 2026-01-19 23:39:53,333, data_manager.py, 107, INFO, Processing year 1998 for ticker SWM.
# 2026-01-19 23:39:53,335, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_1998
# 2026-01-19 23:39:53,340, data_manager.py, 107, INFO, Processing year 1999 for ticker SWM.
# 2026-01-19 23:39:53,342, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_1999
# 2026-01-19 23:39:53,348, data_manager.py, 107, INFO, Processing year 2000 for ticker SWM.
# 2026-01-19 23:39:53,353, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2000
# 2026-01-19 23:39:53,359, data_manager.py, 107, INFO, Processing year 2001 for ticker SWM.
# 2026-01-19 23:39:53,361, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2001
# 2026-01-19 23:39:53,367, data_manager.py, 107, INFO, Processing year 2002 for ticker SWM.
# 2026-01-19 23:39:53,368, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2002
# 2026-01-19 23:39:53,374, data_manager.py, 107, INFO, Processing year 2003 for ticker SWM.
# 2026-01-19 23:39:53,376, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2003
# 2026-01-19 23:39:53,382, data_manager.py, 107, INFO, Processing year 2004 for ticker SWM.
# 2026-01-19 23:39:53,383, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2004
# 2026-01-19 23:39:53,389, data_manager.py, 107, INFO, Processing year 2005 for ticker SWM.
# 2026-01-19 23:39:53,391, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2005
# 2026-01-19 23:39:53,397, data_manager.py, 107, INFO, Processing year 2006 for ticker SWM.
# 2026-01-19 23:39:53,398, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2006
# 2026-01-19 23:39:53,407, data_manager.py, 107, INFO, Processing year 2007 for ticker SWM.
# 2026-01-19 23:39:53,409, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2007
# 2026-01-19 23:39:53,415, data_manager.py, 107, INFO, Processing year 2008 for ticker SWM.
# 2026-01-19 23:39:53,417, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2008
# 2026-01-19 23:39:53,429, data_manager.py, 107, INFO, Processing year 2009 for ticker SWM.
# 2026-01-19 23:39:53,431, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2009
# 2026-01-19 23:39:53,437, data_manager.py, 107, INFO, Processing year 2010 for ticker SWM.
# 2026-01-19 23:39:53,439, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2010
# 2026-01-19 23:39:53,444, data_manager.py, 107, INFO, Processing year 2011 for ticker SWM.
# 2026-01-19 23:39:53,446, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2011
# 2026-01-19 23:39:53,451, data_manager.py, 107, INFO, Processing year 2012 for ticker SWM.
# 2026-01-19 23:39:53,453, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2012
# 2026-01-19 23:39:53,462, data_manager.py, 107, INFO, Processing year 2013 for ticker SWM.
# 2026-01-19 23:39:53,464, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2013
# 2026-01-19 23:39:53,470, data_manager.py, 107, INFO, Processing year 2014 for ticker SWM.
# 2026-01-19 23:39:53,472, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2014
# 2026-01-19 23:39:53,480, data_manager.py, 107, INFO, Processing year 2015 for ticker SWM.
# 2026-01-19 23:39:53,482, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2015
# 2026-01-19 23:39:53,488, data_manager.py, 107, INFO, Processing year 2016 for ticker SWM.
# 2026-01-19 23:39:53,489, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2016
# 2026-01-19 23:39:53,495, data_manager.py, 107, INFO, Processing year 2017 for ticker SWM.
# 2026-01-19 23:39:53,497, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2017
# 2026-01-19 23:39:53,506, data_manager.py, 107, INFO, Processing year 2018 for ticker SWM.
# 2026-01-19 23:39:53,507, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2018
# 2026-01-19 23:39:53,513, data_manager.py, 107, INFO, Processing year 2019 for ticker SWM.
# 2026-01-19 23:39:53,515, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2019
# 2026-01-19 23:39:53,523, data_manager.py, 107, INFO, Processing year 2020 for ticker SWM.
# 2026-01-19 23:39:53,525, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SWM/SWM_2020
# 2026-01-19 23:39:53,530, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/MYD.csv
# 2026-01-19 23:39:53,530, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MYD.csv
# 2026-01-19 23:39:53,534, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:53,539, data_manager.py, 103, INFO, Processing ticker: MYD
# 2026-01-19 23:39:53,540, data_manager.py, 107, INFO, Processing year 1991 for ticker MYD.
# 2026-01-19 23:39:53,542, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_1991
# 2026-01-19 23:39:53,548, data_manager.py, 107, INFO, Processing year 1992 for ticker MYD.
# 2026-01-19 23:39:53,550, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_1992
# 2026-01-19 23:39:53,557, data_manager.py, 107, INFO, Processing year 1993 for ticker MYD.
# 2026-01-19 23:39:53,559, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_1993
# 2026-01-19 23:39:53,565, data_manager.py, 107, INFO, Processing year 1994 for ticker MYD.
# 2026-01-19 23:39:53,566, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_1994
# 2026-01-19 23:39:53,572, data_manager.py, 107, INFO, Processing year 1995 for ticker MYD.
# 2026-01-19 23:39:53,574, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_1995
# 2026-01-19 23:39:53,582, data_manager.py, 107, INFO, Processing year 1996 for ticker MYD.
# 2026-01-19 23:39:53,584, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_1996
# 2026-01-19 23:39:53,589, data_manager.py, 107, INFO, Processing year 1997 for ticker MYD.
# 2026-01-19 23:39:53,591, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_1997
# 2026-01-19 23:39:53,597, data_manager.py, 107, INFO, Processing year 1998 for ticker MYD.
# 2026-01-19 23:39:53,598, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_1998
# 2026-01-19 23:39:53,607, data_manager.py, 107, INFO, Processing year 1999 for ticker MYD.
# 2026-01-19 23:39:53,609, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_1999
# 2026-01-19 23:39:53,616, data_manager.py, 107, INFO, Processing year 2000 for ticker MYD.
# 2026-01-19 23:39:53,618, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2000
# 2026-01-19 23:39:53,623, data_manager.py, 107, INFO, Processing year 2001 for ticker MYD.
# 2026-01-19 23:39:53,625, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2001
# 2026-01-19 23:39:53,631, data_manager.py, 107, INFO, Processing year 2002 for ticker MYD.
# 2026-01-19 23:39:53,632, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2002
# 2026-01-19 23:39:53,640, data_manager.py, 107, INFO, Processing year 2003 for ticker MYD.
# 2026-01-19 23:39:53,642, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2003
# 2026-01-19 23:39:53,648, data_manager.py, 107, INFO, Processing year 2004 for ticker MYD.
# 2026-01-19 23:39:53,650, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2004
# 2026-01-19 23:39:53,659, data_manager.py, 107, INFO, Processing year 2005 for ticker MYD.
# 2026-01-19 23:39:53,661, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2005
# 2026-01-19 23:39:53,667, data_manager.py, 107, INFO, Processing year 2006 for ticker MYD.
# 2026-01-19 23:39:53,669, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2006
# 2026-01-19 23:39:53,675, data_manager.py, 107, INFO, Processing year 2007 for ticker MYD.
# 2026-01-19 23:39:53,677, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2007
# 2026-01-19 23:39:53,685, data_manager.py, 107, INFO, Processing year 2008 for ticker MYD.
# 2026-01-19 23:39:53,687, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2008
# 2026-01-19 23:39:53,693, data_manager.py, 107, INFO, Processing year 2009 for ticker MYD.
# 2026-01-19 23:39:53,694, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2009
# 2026-01-19 23:39:53,700, data_manager.py, 107, INFO, Processing year 2010 for ticker MYD.
# 2026-01-19 23:39:53,701, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2010
# 2026-01-19 23:39:53,709, data_manager.py, 107, INFO, Processing year 2011 for ticker MYD.
# 2026-01-19 23:39:53,711, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2011
# 2026-01-19 23:39:53,716, data_manager.py, 107, INFO, Processing year 2012 for ticker MYD.
# 2026-01-19 23:39:53,717, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2012
# 2026-01-19 23:39:53,722, data_manager.py, 107, INFO, Processing year 2013 for ticker MYD.
# 2026-01-19 23:39:53,724, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2013
# 2026-01-19 23:39:53,732, data_manager.py, 107, INFO, Processing year 2014 for ticker MYD.
# 2026-01-19 23:39:53,733, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2014
# 2026-01-19 23:39:53,738, data_manager.py, 107, INFO, Processing year 2015 for ticker MYD.
# 2026-01-19 23:39:53,740, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2015
# 2026-01-19 23:39:53,750, data_manager.py, 107, INFO, Processing year 2016 for ticker MYD.
# 2026-01-19 23:39:53,752, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2016
# 2026-01-19 23:39:53,759, data_manager.py, 107, INFO, Processing year 2017 for ticker MYD.
# 2026-01-19 23:39:53,760, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2017
# 2026-01-19 23:39:53,771, data_manager.py, 107, INFO, Processing year 2018 for ticker MYD.
# 2026-01-19 23:39:53,773, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2018
# 2026-01-19 23:39:53,779, data_manager.py, 107, INFO, Processing year 2019 for ticker MYD.
# 2026-01-19 23:39:53,780, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2019
# 2026-01-19 23:39:53,786, data_manager.py, 107, INFO, Processing year 2020 for ticker MYD.
# 2026-01-19 23:39:53,787, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/MYD/MYD_2020
# 2026-01-19 23:39:53,793, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/EVBN.csv
# 2026-01-19 23:39:53,793, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EVBN.csv
# 2026-01-19 23:39:53,797, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:53,797, data_manager.py, 103, INFO, Processing ticker: EVBN
# 2026-01-19 23:39:53,798, data_manager.py, 107, INFO, Processing year 2002 for ticker EVBN.
# 2026-01-19 23:39:53,800, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2002
# 2026-01-19 23:39:53,808, data_manager.py, 107, INFO, Processing year 2003 for ticker EVBN.
# 2026-01-19 23:39:53,810, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2003
# 2026-01-19 23:39:53,816, data_manager.py, 107, INFO, Processing year 2004 for ticker EVBN.
# 2026-01-19 23:39:53,818, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2004
# 2026-01-19 23:39:53,823, data_manager.py, 107, INFO, Processing year 2005 for ticker EVBN.
# 2026-01-19 23:39:53,825, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2005
# 2026-01-19 23:39:53,832, data_manager.py, 107, INFO, Processing year 2006 for ticker EVBN.
# 2026-01-19 23:39:53,834, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2006
# 2026-01-19 23:39:53,839, data_manager.py, 107, INFO, Processing year 2007 for ticker EVBN.
# 2026-01-19 23:39:53,841, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2007
# 2026-01-19 23:39:53,847, data_manager.py, 107, INFO, Processing year 2008 for ticker EVBN.
# 2026-01-19 23:39:53,848, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2008
# 2026-01-19 23:39:53,858, data_manager.py, 107, INFO, Processing year 2009 for ticker EVBN.
# 2026-01-19 23:39:53,860, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2009
# 2026-01-19 23:39:53,866, data_manager.py, 107, INFO, Processing year 2010 for ticker EVBN.
# 2026-01-19 23:39:53,868, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2010
# 2026-01-19 23:39:53,878, data_manager.py, 107, INFO, Processing year 2011 for ticker EVBN.
# 2026-01-19 23:39:53,879, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2011
# 2026-01-19 23:39:53,885, data_manager.py, 107, INFO, Processing year 2012 for ticker EVBN.
# 2026-01-19 23:39:53,886, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2012
# 2026-01-19 23:39:53,893, data_manager.py, 107, INFO, Processing year 2013 for ticker EVBN.
# 2026-01-19 23:39:53,895, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2013
# 2026-01-19 23:39:53,900, data_manager.py, 107, INFO, Processing year 2014 for ticker EVBN.
# 2026-01-19 23:39:53,902, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2014
# 2026-01-19 23:39:53,907, data_manager.py, 107, INFO, Processing year 2015 for ticker EVBN.
# 2026-01-19 23:39:53,909, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2015
# 2026-01-19 23:39:53,919, data_manager.py, 107, INFO, Processing year 2016 for ticker EVBN.
# 2026-01-19 23:39:53,920, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2016
# 2026-01-19 23:39:53,929, data_manager.py, 107, INFO, Processing year 2017 for ticker EVBN.
# 2026-01-19 23:39:53,930, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/EVBN/EVBN_2017
# 2026-01-19 23:39:53,936, data_manager.py, 107, INFO, Processing year 2018 for ticker EVBN.
# ...
# 2026-01-19 23:39:55,178, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BTAL/BTAL_2016
# 2026-01-19 23:39:55,188, data_manager.py, 107, INFO, Processing year 2017 for ticker BTAL.
# 2026-01-19 23:39:55,190, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BTAL/BTAL_2017
# 2026-01-19 23:39:55,196, data_manager.py, 107, INFO, Processing year 2018 for ticker BTAL.
# 2026-01-19 23:39:55,198, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BTAL/BTAL_2018
# 2026-01-19 23:39:55,204, data_manager.py, 107, INFO, Processing year 2019 for ticker BTAL.
# 2026-01-19 23:39:55,205, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BTAL/BTAL_2019
# 2026-01-19 23:39:55,214, data_manager.py, 107, INFO, Processing year 2020 for ticker BTAL.
# 2026-01-19 23:39:55,216, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/BTAL/BTAL_2020
# 2026-01-19 23:39:55,221, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/CPF.csv
# 2026-01-19 23:39:55,221, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CPF.csv
# 2026-01-19 23:39:55,226, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:55,226, data_manager.py, 103, INFO, Processing ticker: CPF
# 2026-01-19 23:39:55,228, data_manager.py, 107, INFO, Processing year 1987 for ticker CPF.
# 2026-01-19 23:39:55,230, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1987
# 2026-01-19 23:39:55,239, data_manager.py, 107, INFO, Processing year 1988 for ticker CPF.
# 2026-01-19 23:39:55,240, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1988
# 2026-01-19 23:39:55,246, data_manager.py, 107, INFO, Processing year 1989 for ticker CPF.
# 2026-01-19 23:39:55,247, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1989
# 2026-01-19 23:39:55,256, data_manager.py, 107, INFO, Processing year 1990 for ticker CPF.
# 2026-01-19 23:39:55,257, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1990
# 2026-01-19 23:39:55,263, data_manager.py, 107, INFO, Processing year 1991 for ticker CPF.
# 2026-01-19 23:39:55,264, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1991
# 2026-01-19 23:39:55,275, data_manager.py, 107, INFO, Processing year 1992 for ticker CPF.
# 2026-01-19 23:39:55,276, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1992
# 2026-01-19 23:39:55,282, data_manager.py, 107, INFO, Processing year 1993 for ticker CPF.
# 2026-01-19 23:39:55,284, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1993
# 2026-01-19 23:39:55,289, data_manager.py, 107, INFO, Processing year 1994 for ticker CPF.
# 2026-01-19 23:39:55,291, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1994
# 2026-01-19 23:39:55,299, data_manager.py, 107, INFO, Processing year 1995 for ticker CPF.
# 2026-01-19 23:39:55,301, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1995
# 2026-01-19 23:39:55,307, data_manager.py, 107, INFO, Processing year 1996 for ticker CPF.
# 2026-01-19 23:39:55,308, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1996
# 2026-01-19 23:39:55,318, data_manager.py, 107, INFO, Processing year 1997 for ticker CPF.
# 2026-01-19 23:39:55,319, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1997
# 2026-01-19 23:39:55,324, data_manager.py, 107, INFO, Processing year 1998 for ticker CPF.
# 2026-01-19 23:39:55,326, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1998
# 2026-01-19 23:39:55,334, data_manager.py, 107, INFO, Processing year 1999 for ticker CPF.
# 2026-01-19 23:39:55,335, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_1999
# 2026-01-19 23:39:55,340, data_manager.py, 107, INFO, Processing year 2000 for ticker CPF.
# 2026-01-19 23:39:55,341, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2000
# 2026-01-19 23:39:55,351, data_manager.py, 107, INFO, Processing year 2001 for ticker CPF.
# 2026-01-19 23:39:55,353, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2001
# 2026-01-19 23:39:55,361, data_manager.py, 107, INFO, Processing year 2002 for ticker CPF.
# 2026-01-19 23:39:55,363, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2002
# 2026-01-19 23:39:55,368, data_manager.py, 107, INFO, Processing year 2003 for ticker CPF.
# 2026-01-19 23:39:55,370, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2003
# 2026-01-19 23:39:55,376, data_manager.py, 107, INFO, Processing year 2004 for ticker CPF.
# 2026-01-19 23:39:55,377, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2004
# 2026-01-19 23:39:55,383, data_manager.py, 107, INFO, Processing year 2005 for ticker CPF.
# 2026-01-19 23:39:55,384, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2005
# 2026-01-19 23:39:55,394, data_manager.py, 107, INFO, Processing year 2006 for ticker CPF.
# 2026-01-19 23:39:55,396, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2006
# 2026-01-19 23:39:55,401, data_manager.py, 107, INFO, Processing year 2007 for ticker CPF.
# 2026-01-19 23:39:55,403, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2007
# 2026-01-19 23:39:55,409, data_manager.py, 107, INFO, Processing year 2008 for ticker CPF.
# 2026-01-19 23:39:55,411, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2008
# 2026-01-19 23:39:55,416, data_manager.py, 107, INFO, Processing year 2009 for ticker CPF.
# 2026-01-19 23:39:55,418, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2009
# 2026-01-19 23:39:55,424, data_manager.py, 107, INFO, Processing year 2010 for ticker CPF.
# 2026-01-19 23:39:55,425, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2010
# 2026-01-19 23:39:55,434, data_manager.py, 107, INFO, Processing year 2011 for ticker CPF.
# 2026-01-19 23:39:55,435, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2011
# 2026-01-19 23:39:55,442, data_manager.py, 107, INFO, Processing year 2012 for ticker CPF.
# 2026-01-19 23:39:55,444, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2012
# 2026-01-19 23:39:55,453, data_manager.py, 107, INFO, Processing year 2013 for ticker CPF.
# 2026-01-19 23:39:55,455, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2013
# 2026-01-19 23:39:55,463, data_manager.py, 107, INFO, Processing year 2014 for ticker CPF.
# 2026-01-19 23:39:55,465, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2014
# 2026-01-19 23:39:55,475, data_manager.py, 107, INFO, Processing year 2015 for ticker CPF.
# 2026-01-19 23:39:55,478, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2015
# 2026-01-19 23:39:55,484, data_manager.py, 107, INFO, Processing year 2016 for ticker CPF.
# 2026-01-19 23:39:55,485, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2016
# 2026-01-19 23:39:55,491, data_manager.py, 107, INFO, Processing year 2017 for ticker CPF.
# 2026-01-19 23:39:55,493, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2017
# 2026-01-19 23:39:55,500, data_manager.py, 107, INFO, Processing year 2018 for ticker CPF.
# 2026-01-19 23:39:55,502, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2018
# 2026-01-19 23:39:55,508, data_manager.py, 107, INFO, Processing year 2019 for ticker CPF.
# 2026-01-19 23:39:55,510, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2019
# 2026-01-19 23:39:55,519, data_manager.py, 107, INFO, Processing year 2020 for ticker CPF.
# 2026-01-19 23:39:55,521, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/CPF/CPF_2020
# 2026-01-19 23:39:55,527, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/SIGA.csv
# 2026-01-19 23:39:55,527, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SIGA.csv
# 2026-01-19 23:39:55,531, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:55,532, data_manager.py, 103, INFO, Processing ticker: SIGA
# 2026-01-19 23:39:55,533, data_manager.py, 107, INFO, Processing year 1997 for ticker SIGA.
# 2026-01-19 23:39:55,535, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_1997
# 2026-01-19 23:39:55,540, data_manager.py, 107, INFO, Processing year 1998 for ticker SIGA.
# 2026-01-19 23:39:55,542, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_1998
# 2026-01-19 23:39:55,551, data_manager.py, 107, INFO, Processing year 1999 for ticker SIGA.
# 2026-01-19 23:39:55,552, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_1999
# 2026-01-19 23:39:55,558, data_manager.py, 107, INFO, Processing year 2000 for ticker SIGA.
# 2026-01-19 23:39:55,559, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2000
# 2026-01-19 23:39:55,567, data_manager.py, 107, INFO, Processing year 2001 for ticker SIGA.
# 2026-01-19 23:39:55,569, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2001
# 2026-01-19 23:39:55,575, data_manager.py, 107, INFO, Processing year 2002 for ticker SIGA.
# 2026-01-19 23:39:55,576, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2002
# 2026-01-19 23:39:55,583, data_manager.py, 107, INFO, Processing year 2003 for ticker SIGA.
# 2026-01-19 23:39:55,584, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2003
# 2026-01-19 23:39:55,592, data_manager.py, 107, INFO, Processing year 2004 for ticker SIGA.
# 2026-01-19 23:39:55,594, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2004
# 2026-01-19 23:39:55,600, data_manager.py, 107, INFO, Processing year 2005 for ticker SIGA.
# 2026-01-19 23:39:55,601, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2005
# 2026-01-19 23:39:55,611, data_manager.py, 107, INFO, Processing year 2006 for ticker SIGA.
# 2026-01-19 23:39:55,613, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2006
# 2026-01-19 23:39:55,619, data_manager.py, 107, INFO, Processing year 2007 for ticker SIGA.
# 2026-01-19 23:39:55,621, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2007
# 2026-01-19 23:39:55,626, data_manager.py, 107, INFO, Processing year 2008 for ticker SIGA.
# 2026-01-19 23:39:55,628, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2008
# 2026-01-19 23:39:55,633, data_manager.py, 107, INFO, Processing year 2009 for ticker SIGA.
# 2026-01-19 23:39:55,635, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2009
# 2026-01-19 23:39:55,640, data_manager.py, 107, INFO, Processing year 2010 for ticker SIGA.
# 2026-01-19 23:39:55,642, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2010
# 2026-01-19 23:39:55,647, data_manager.py, 107, INFO, Processing year 2011 for ticker SIGA.
# 2026-01-19 23:39:55,649, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2011
# 2026-01-19 23:39:55,654, data_manager.py, 107, INFO, Processing year 2012 for ticker SIGA.
# 2026-01-19 23:39:55,656, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2012
# 2026-01-19 23:39:55,661, data_manager.py, 107, INFO, Processing year 2013 for ticker SIGA.
# 2026-01-19 23:39:55,663, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2013
# 2026-01-19 23:39:55,674, data_manager.py, 107, INFO, Processing year 2014 for ticker SIGA.
# 2026-01-19 23:39:55,676, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2014
# 2026-01-19 23:39:55,681, data_manager.py, 107, INFO, Processing year 2015 for ticker SIGA.
# 2026-01-19 23:39:55,683, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2015
# 2026-01-19 23:39:55,688, data_manager.py, 107, INFO, Processing year 2016 for ticker SIGA.
# 2026-01-19 23:39:55,690, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2016
# 2026-01-19 23:39:55,696, data_manager.py, 107, INFO, Processing year 2017 for ticker SIGA.
# 2026-01-19 23:39:55,698, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2017
# 2026-01-19 23:39:55,704, data_manager.py, 107, INFO, Processing year 2018 for ticker SIGA.
# 2026-01-19 23:39:55,706, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2018
# 2026-01-19 23:39:55,712, data_manager.py, 107, INFO, Processing year 2019 for ticker SIGA.
# 2026-01-19 23:39:55,713, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2019
# 2026-01-19 23:39:55,722, data_manager.py, 107, INFO, Processing year 2020 for ticker SIGA.
# 2026-01-19 23:39:55,723, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/SIGA/SIGA_2020
# 2026-01-19 23:39:55,729, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/FSMB.csv
# 2026-01-19 23:39:55,729, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/etfs/FSMB.csv
# 2026-01-19 23:39:55,731, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:55,731, data_manager.py, 103, INFO, Processing ticker: FSMB
# 2026-01-19 23:39:55,732, data_manager.py, 107, INFO, Processing year 2018 for ticker FSMB.
# 2026-01-19 23:39:55,733, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FSMB/FSMB_2018
# 2026-01-19 23:39:55,746, data_manager.py, 107, INFO, Processing year 2019 for ticker FSMB.
# 2026-01-19 23:39:55,749, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FSMB/FSMB_2019
# 2026-01-19 23:39:55,755, data_manager.py, 107, INFO, Processing year 2020 for ticker FSMB.
# 2026-01-19 23:39:55,757, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/FSMB/FSMB_2020
# 2026-01-19 23:39:55,763, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/JHMI.csv
# 2026-01-19 23:39:55,763, data_manager.py, 121, INFO, Reading file: ../../05_src/data/prices_csv/etfs/JHMI.csv
# 2026-01-19 23:39:55,765, data_manager.py, 101, INFO, Saving data by year
# 2026-01-19 23:39:55,765, data_manager.py, 103, INFO, Processing ticker: JHMI
# 2026-01-19 23:39:55,765, data_manager.py, 107, INFO, Processing year 2016 for ticker JHMI.
# 2026-01-19 23:39:55,767, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/JHMI/JHMI_2016
# 2026-01-19 23:39:55,773, data_manager.py, 107, INFO, Processing year 2017 for ticker JHMI.
# 2026-01-19 23:39:55,775, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/JHMI/JHMI_2017
# 2026-01-19 23:39:55,784, data_manager.py, 107, INFO, Processing year 2018 for ticker JHMI.
# 2026-01-19 23:39:55,786, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/JHMI/JHMI_2018
# 2026-01-19 23:39:55,792, data_manager.py, 107, INFO, Processing year 2019 for ticker JHMI.
# 2026-01-19 23:39:55,793, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/JHMI/JHMI_2019
# 2026-01-19 23:39:55,799, data_manager.py, 107, INFO, Processing year 2020 for ticker JHMI.
# 2026-01-19 23:39:55,801, data_manager.py, 111, INFO, Writing data to path: ../../05_src/data/prices/JHMI/JHMI_2020

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2026-01-19 23:39:59,025, data_manager.py, 134, INFO, Creating features data.
# 2026-01-19 23:39:59,026, data_manager.py, 144, INFO, Loading price data from ../../05_src/data/prices/
# 2026-01-19 23:39:59,202, data_manager.py, 153, INFO, Creating features
# 2026-01-19 23:39:59,206, data_manager.py, 184, INFO, Saving features to ../../05_src/data/features/stock_features
